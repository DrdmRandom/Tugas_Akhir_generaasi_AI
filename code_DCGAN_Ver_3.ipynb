# %% [markdown]
# ###  Importing Library

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.utils import make_grid, save_image
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# #### Hyperparameters

# %%
batch_size = 64
image_size = 64       # resolusi gambar (64x64)
nz = 100              # dimensi vektor noise (input generator)
num_epochs = 500        # silakan disesuaikan
lr = 0.0005
beta1 = 0.5
ngf = 64  # generator feature map size
ndf = 64  # discriminator feature map size
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Memeriksa apakah CUDA tersedia
print(torch.cuda.is_available())

# Jika True, berarti GPU Anda bisa digunakan oleh PyTorch
# Nama GPU (untuk device index 0)
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
    print(torch.version.cuda)
# Out:
# True
# NVIDIA GeForce GTX 1060 6GB
# 11.8

# %% [markdown]
# #### Persiapan Dataset & DataLoader

# %%
# data_dir = r"dataset-path-here"
#
# # Transform (augmentasi, normalisasi) seperti sebelumnya
# transform = transforms.Compose([
#     transforms.Resize(image_size),
#     transforms.CenterCrop(image_size),
#     transforms.ToTensor(),
#     transforms.Normalize([0.5]*3, [0.5]*3)  # normalisasi ke [-1,1]
# ])
#
# # Buat dataset
# dataset = torchvision.datasets.ImageFolder(
#     root=data_dir,
#     transform=transform
# )
#
# # SubsetRandomSampler
# indices = list(range(len(dataset)))
# np.random.shuffle(indices)
#
# # Misalnya ingin 1000 sample acak
# subset_size = 1000
# subset_indices = indices[:subset_size]
#
# sampler = SubsetRandomSampler(subset_indices)
#
# # DataLoader dengan sampler (ganti 'shuffle=True' dengan 'sampler=sampler')
# dataloader = DataLoader(
#     dataset,
#     batch_size=batch_size,
#     sampler=sampler,
#     num_workers=2
# )

# %%
data_dir = r"dataset-path-here"  # ganti dengan path dataset Anda

transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)  # normalisasi [-1, 1]
])

dataset = torchvision.datasets.ImageFolder(
    root=data_dir,
    transform=transform
)

dataloader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2
)

# %% [markdown]
# #### Definisi Arsitektur DCGAN

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, nz, ngf, nc=3):
        """
        nz : ukuran noise vector
        ngf: ukuran base feature di generator
        nc : jumlah channel pada output (3 untuk RGB)
        """
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # input Z berukuran nz x 1 x 1
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),

            # state size: (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),

            # state size: (ngf*4) x 8 x 8
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),

            # state size: (ngf*2) x 16 x 16
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),

            # state size: (ngf) x 32 x 32
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size: (nc) x 64 x 64
        )

    def forward(self, x):
        return self.main(x)

# %%
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, ndf, nc=3):
        """
        ndf: ukuran base feature di discriminator
        nc : jumlah channel input (3 untuk RGB)
        """
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            # input size: (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
            # output shape: 1
        )

    def forward(self, x):
        return self.main(x)

# Inisialisasi model
netG = Generator(nz, ngf).to(device)
netD = Discriminator(ndf).to(device)

# %% [markdown]
# #### Loss function & Optimizer

# %%
criterion = nn.BCELoss()
optimizerD = torch.optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = torch.optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %% [markdown]
# #### Training

# %%
lossD_history = []
lossG_history = []

fixed_noise = torch.randn(batch_size, nz, 1, 1, device=device)

# label real dan fake
real_label = 1.
fake_label = 0.

# Simpan sample G setiap epoch
os.makedirs("samples", exist_ok=True)

print("Start Training...")
for epoch in range(num_epochs):
    for i, (imgs, _) in enumerate(dataloader):
        # ----------------------
        # 1) Update D
        # ----------------------
        netD.zero_grad()

        # Train with real
        real_imgs = imgs.to(device)
        b_size = real_imgs.size(0)

        label_real = torch.full((b_size,), 1., dtype=torch.float, device=device)
        label_fake = torch.full((b_size,), 0., dtype=torch.float, device=device)

        output_real = netD(real_imgs).view(-1)
        lossD_real = criterion(output_real, label_real)

        # Train with fake
        noise = torch.randn(b_size, nz, 1, 1, device=device)
        fake_imgs = netG(noise)

        output_fake = netD(fake_imgs.detach()).view(-1)
        lossD_fake = criterion(output_fake, label_fake)

        lossD_total = lossD_real + lossD_fake
        lossD_total.backward()
        optimizerD.step()

        # ----------------------
        # 2) Update G
        # ----------------------
        netG.zero_grad()
        # Generator wants D(G(z)) = 1
        output_fake_for_G = netD(fake_imgs).view(-1)
        lossG_total = criterion(output_fake_for_G, label_real)
        lossG_total.backward()
        optimizerG.step()

        # Simpan history loss (opsional: per batch, atau rata2 per epoch)
        lossD_history.append(lossD_total.item())
        lossG_history.append(lossG_total.item())

        if i % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}] Batch [{i}/{len(dataloader)}] "
                  f"LossD: {lossD_total.item():.4f} LossG: {lossG_total.item():.4f}")

    # Simpan sample images di akhir epoch
    with torch.no_grad():
        fake = netG(fixed_noise).detach().cpu()
    grid = make_grid(fake, nrow=8, normalize=True)
    save_image(grid, f"samples/epoch_{epoch+1}.png")
    print(f"Sample image saved: samples/epoch_{epoch+1}.png")

print("Training Finished.")
# Out:
# Start Training...
# Epoch [1/500] Batch [0/3682] LossD: 1.3656 LossG: 5.9016
# Epoch [1/500] Batch [100/3682] LossD: 0.7608 LossG: 6.4232
# Epoch [1/500] Batch [200/3682] LossD: 0.8118 LossG: 2.0025
# Epoch [1/500] Batch [300/3682] LossD: 1.0589 LossG: 3.6434
# Epoch [1/500] Batch [400/3682] LossD: 0.8556 LossG: 2.4988
# Epoch [1/500] Batch [500/3682] LossD: 0.7577 LossG: 3.9646
# Epoch [1/500] Batch [600/3682] LossD: 0.8976 LossG: 2.9960
# Epoch [1/500] Batch [700/3682] LossD: 1.1644 LossG: 2.0739
# Epoch [1/500] Batch [800/3682] LossD: 0.9667 LossG: 2.6888
# Epoch [1/500] Batch [900/3682] LossD: 0.5571 LossG: 3.9872
# Epoch [1/500] Batch [1000/3682] LossD: 0.7624 LossG: 5.1003
# Epoch [1/500] Batch [1100/3682] LossD: 1.0259 LossG: 2.5125
# Epoch [1/500] Batch [1200/3682] LossD: 1.0154 LossG: 2.7966
# Epoch [1/500] Batch [1300/3682] LossD: 0.7819 LossG: 2.8849
# Epoch [1/500] Batch [1400/3682] LossD: 0.5314 LossG: 3.9402
# Epoch [1/500] Batch [1500/3682] LossD: 0.7034 LossG: 2.9903
# Epoch [1/500] Batch [1600/3682] LossD: 0.5517 LossG: 4.9499
# Epoch [1/500] Batch [1700/3682] LossD: 0.4553 LossG: 3.9894
# Epoch [1/500] Batch [1800/3682] LossD: 1.0976 LossG: 0.7250
# Epoch [1/500] Batch [1900/3682] LossD: 0.5018 LossG: 3.1439
# Epoch [1/500] Batch [2000/3682] LossD: 0.2977 LossG: 3.7702
# Epoch [1/500] Batch [2100/3682] LossD: 0.5341 LossG: 3.1477
# Epoch [1/500] Batch [2200/3682] LossD: 0.4244 LossG: 5.8243
# Epoch [1/500] Batch [2300/3682] LossD: 0.3787 LossG: 5.9372
# Epoch [1/500] Batch [2400/3682] LossD: 1.1691 LossG: 5.7415
# Epoch [1/500] Batch [2500/3682] LossD: 0.9779 LossG: 8.1136
# Epoch [1/500] Batch [2600/3682] LossD: 1.5739 LossG: 8.5112
# Epoch [1/500] Batch [2700/3682] LossD: 0.4267 LossG: 5.6719
# Epoch [1/500] Batch [2800/3682] LossD: 0.6643 LossG: 5.4433
# Epoch [1/500] Batch [2900/3682] LossD: 0.3847 LossG: 3.6991
# Epoch [1/500] Batch [3000/3682] LossD: 0.4719 LossG: 3.0209
# Epoch [1/500] Batch [3100/3682] LossD: 0.3962 LossG: 4.8984
# Epoch [1/500] Batch [3200/3682] LossD: 0.6129 LossG: 6.8647
# Epoch [1/500] Batch [3300/3682] LossD: 0.2932 LossG: 4.7535
# Epoch [1/500] Batch [3400/3682] LossD: 0.8408 LossG: 7.0879
# Epoch [1/500] Batch [3500/3682] LossD: 0.4530 LossG: 2.4900
# Epoch [1/500] Batch [3600/3682] LossD: 1.3240 LossG: 1.6476
# Sample image saved: samples/epoch_1.png
# Epoch [2/500] Batch [0/3682] LossD: 0.2825 LossG: 4.3830
# Epoch [2/500] Batch [100/3682] LossD: 0.6764 LossG: 7.5248
# Epoch [2/500] Batch [200/3682] LossD: 0.5516 LossG: 3.6996
# Epoch [2/500] Batch [300/3682] LossD: 0.4336 LossG: 4.2752
# Epoch [2/500] Batch [400/3682] LossD: 0.7384 LossG: 1.8554
# Epoch [2/500] Batch [500/3682] LossD: 0.7655 LossG: 6.5889
# Epoch [2/500] Batch [600/3682] LossD: 0.7584 LossG: 2.1256
# Epoch [2/500] Batch [700/3682] LossD: 1.3885 LossG: 5.0229
# Epoch [2/500] Batch [800/3682] LossD: 0.2614 LossG: 5.2337
# Epoch [2/500] Batch [900/3682] LossD: 0.2962 LossG: 2.7839
# Epoch [2/500] Batch [1000/3682] LossD: 1.1332 LossG: 8.2822
# Epoch [2/500] Batch [1100/3682] LossD: 0.5376 LossG: 1.7031
# Epoch [2/500] Batch [1200/3682] LossD: 0.3983 LossG: 2.9869
# Epoch [2/500] Batch [1300/3682] LossD: 0.3581 LossG: 3.6001
# Epoch [2/500] Batch [1400/3682] LossD: 0.6806 LossG: 2.1027
# Epoch [2/500] Batch [1500/3682] LossD: 0.2918 LossG: 4.6017
# Epoch [2/500] Batch [1600/3682] LossD: 0.4744 LossG: 2.4352
# Epoch [2/500] Batch [1700/3682] LossD: 0.8394 LossG: 7.4433
# Epoch [2/500] Batch [1800/3682] LossD: 0.3623 LossG: 4.9145
# Epoch [2/500] Batch [1900/3682] LossD: 0.2471 LossG: 3.6504
# Epoch [2/500] Batch [2000/3682] LossD: 0.5068 LossG: 1.3990
# Epoch [2/500] Batch [2100/3682] LossD: 0.1850 LossG: 3.8694
# Epoch [2/500] Batch [2200/3682] LossD: 0.4026 LossG: 2.5052
# Epoch [2/500] Batch [2300/3682] LossD: 0.3377 LossG: 4.7305
# Epoch [2/500] Batch [2400/3682] LossD: 0.6236 LossG: 2.8056
# Epoch [2/500] Batch [2500/3682] LossD: 0.3391 LossG: 2.2830
# Epoch [2/500] Batch [2600/3682] LossD: 0.2132 LossG: 3.7533
# Epoch [2/500] Batch [2700/3682] LossD: 0.2539 LossG: 3.2106
# Epoch [2/500] Batch [2800/3682] LossD: 0.2382 LossG: 4.3825
# Epoch [2/500] Batch [2900/3682] LossD: 0.5831 LossG: 2.4799
# Epoch [2/500] Batch [3000/3682] LossD: 0.4650 LossG: 8.8009
# Epoch [2/500] Batch [3100/3682] LossD: 0.9980 LossG: 8.9177
# Epoch [2/500] Batch [3200/3682] LossD: 0.2720 LossG: 3.5326
# Epoch [2/500] Batch [3300/3682] LossD: 0.1995 LossG: 4.2307
# Epoch [2/500] Batch [3400/3682] LossD: 1.9487 LossG: 2.0254
# Epoch [2/500] Batch [3500/3682] LossD: 0.7569 LossG: 2.6057
# Epoch [2/500] Batch [3600/3682] LossD: 0.3414 LossG: 5.7195
# Sample image saved: samples/epoch_2.png
# Epoch [3/500] Batch [0/3682] LossD: 0.1906 LossG: 3.4136
# Epoch [3/500] Batch [100/3682] LossD: 0.3536 LossG: 3.1125
# Epoch [3/500] Batch [200/3682] LossD: 0.2981 LossG: 3.2045
# Epoch [3/500] Batch [300/3682] LossD: 0.3463 LossG: 4.9720
# Epoch [3/500] Batch [400/3682] LossD: 0.1128 LossG: 5.5255
# Epoch [3/500] Batch [500/3682] LossD: 1.1749 LossG: 1.8416
# Epoch [3/500] Batch [600/3682] LossD: 0.5234 LossG: 6.3756
# Epoch [3/500] Batch [700/3682] LossD: 1.0114 LossG: 6.9991
# Epoch [3/500] Batch [800/3682] LossD: 0.5523 LossG: 6.6177
# Epoch [3/500] Batch [900/3682] LossD: 0.0884 LossG: 5.3219
# Epoch [3/500] Batch [1000/3682] LossD: 0.1779 LossG: 5.1723
# Epoch [3/500] Batch [1100/3682] LossD: 0.3800 LossG: 5.0275
# Epoch [3/500] Batch [1200/3682] LossD: 0.1752 LossG: 4.8487
# Epoch [3/500] Batch [1300/3682] LossD: 3.7089 LossG: 0.0169
# Epoch [3/500] Batch [1400/3682] LossD: 0.1808 LossG: 3.5187
# Epoch [3/500] Batch [1500/3682] LossD: 0.2765 LossG: 3.4340
# Epoch [3/500] Batch [1600/3682] LossD: 0.2710 LossG: 5.1827
# Epoch [3/500] Batch [1700/3682] LossD: 0.1164 LossG: 4.1376
# Epoch [3/500] Batch [1800/3682] LossD: 0.1131 LossG: 5.3555
# Epoch [3/500] Batch [1900/3682] LossD: 0.0894 LossG: 4.9804
# Epoch [3/500] Batch [2000/3682] LossD: 0.3034 LossG: 5.0932
# Epoch [3/500] Batch [2100/3682] LossD: 0.1666 LossG: 3.6433
# Epoch [3/500] Batch [2200/3682] LossD: 0.3071 LossG: 7.3816
# Epoch [3/500] Batch [2300/3682] LossD: 0.2499 LossG: 6.3225
# Epoch [3/500] Batch [2400/3682] LossD: 0.2218 LossG: 6.6678
# Epoch [3/500] Batch [2500/3682] LossD: 0.0904 LossG: 5.4934
# Epoch [3/500] Batch [2600/3682] LossD: 0.3609 LossG: 2.1710
# Epoch [3/500] Batch [2700/3682] LossD: 0.1769 LossG: 4.8233
# Epoch [3/500] Batch [2800/3682] LossD: 0.6536 LossG: 4.9774
# Epoch [3/500] Batch [2900/3682] LossD: 0.2946 LossG: 6.9196
# Epoch [3/500] Batch [3000/3682] LossD: 0.6656 LossG: 2.5881
# Epoch [3/500] Batch [3100/3682] LossD: 0.1921 LossG: 5.5552
# Epoch [3/500] Batch [3200/3682] LossD: 0.2522 LossG: 3.2501
# Epoch [3/500] Batch [3300/3682] LossD: 0.2460 LossG: 6.4011
# Epoch [3/500] Batch [3400/3682] LossD: 0.1341 LossG: 4.7843
# Epoch [3/500] Batch [3500/3682] LossD: 0.3194 LossG: 6.2703
# Epoch [3/500] Batch [3600/3682] LossD: 0.2754 LossG: 4.1811
# Sample image saved: samples/epoch_3.png
# Epoch [4/500] Batch [0/3682] LossD: 0.0998 LossG: 4.3525
# Epoch [4/500] Batch [100/3682] LossD: 0.1110 LossG: 4.9420
# Epoch [4/500] Batch [200/3682] LossD: 0.1268 LossG: 4.1624
# Epoch [4/500] Batch [300/3682] LossD: 0.2936 LossG: 6.0156
# Epoch [4/500] Batch [400/3682] LossD: 0.0825 LossG: 4.3532
# Epoch [4/500] Batch [500/3682] LossD: 0.0506 LossG: 5.4604
# Epoch [4/500] Batch [600/3682] LossD: 2.9833 LossG: 0.8573
# Epoch [4/500] Batch [700/3682] LossD: 0.6994 LossG: 2.0778
# Epoch [4/500] Batch [800/3682] LossD: 0.1290 LossG: 3.7374
# Epoch [4/500] Batch [900/3682] LossD: 0.0832 LossG: 4.4722
# Epoch [4/500] Batch [1000/3682] LossD: 0.1720 LossG: 4.4615
# Epoch [4/500] Batch [1100/3682] LossD: 0.1962 LossG: 4.0714
# Epoch [4/500] Batch [1200/3682] LossD: 0.1997 LossG: 2.9833
# Epoch [4/500] Batch [1300/3682] LossD: 2.1763 LossG: 0.6403
# Epoch [4/500] Batch [1400/3682] LossD: 0.1134 LossG: 3.9176
# Epoch [4/500] Batch [1500/3682] LossD: 0.2428 LossG: 3.5362
# Epoch [4/500] Batch [1600/3682] LossD: 1.3203 LossG: 3.3859
# Epoch [4/500] Batch [1700/3682] LossD: 0.6507 LossG: 10.3309
# Epoch [4/500] Batch [1800/3682] LossD: 0.3360 LossG: 6.4178
# Epoch [4/500] Batch [1900/3682] LossD: 0.0955 LossG: 4.5771
# Epoch [4/500] Batch [2000/3682] LossD: 0.1198 LossG: 3.7046
# Epoch [4/500] Batch [2100/3682] LossD: 0.5975 LossG: 4.9572
# Epoch [4/500] Batch [2200/3682] LossD: 3.2009 LossG: 0.2688
# Epoch [4/500] Batch [2300/3682] LossD: 0.2152 LossG: 5.3783
# Epoch [4/500] Batch [2400/3682] LossD: 0.1257 LossG: 4.5097
# Epoch [4/500] Batch [2500/3682] LossD: 0.0484 LossG: 5.1772
# Epoch [4/500] Batch [2600/3682] LossD: 0.2869 LossG: 5.5918
# Epoch [4/500] Batch [2700/3682] LossD: 0.1761 LossG: 4.1681
# Epoch [4/500] Batch [2800/3682] LossD: 0.0648 LossG: 5.3248
# Epoch [4/500] Batch [2900/3682] LossD: 0.1544 LossG: 3.3604
# Epoch [4/500] Batch [3000/3682] LossD: 0.1260 LossG: 6.3254
# Epoch [4/500] Batch [3100/3682] LossD: 0.0747 LossG: 7.9516
# Epoch [4/500] Batch [3200/3682] LossD: 0.0465 LossG: 5.0902
# Epoch [4/500] Batch [3300/3682] LossD: 0.0616 LossG: 5.8815
# Epoch [4/500] Batch [3400/3682] LossD: 0.2625 LossG: 4.7942
# Epoch [4/500] Batch [3500/3682] LossD: 0.3462 LossG: 7.6743
# Epoch [4/500] Batch [3600/3682] LossD: 0.0782 LossG: 4.8735
# Sample image saved: samples/epoch_4.png
# Epoch [5/500] Batch [0/3682] LossD: 0.1076 LossG: 5.7493
# Epoch [5/500] Batch [100/3682] LossD: 0.9344 LossG: 3.7082
# Epoch [5/500] Batch [200/3682] LossD: 0.1246 LossG: 5.0319
# Epoch [5/500] Batch [300/3682] LossD: 0.2721 LossG: 2.6571
# Epoch [5/500] Batch [400/3682] LossD: 0.0473 LossG: 5.7428
# Epoch [5/500] Batch [500/3682] LossD: 0.0310 LossG: 5.8066
# Epoch [5/500] Batch [600/3682] LossD: 0.1046 LossG: 5.9402
# Epoch [5/500] Batch [700/3682] LossD: 0.0682 LossG: 5.9540
# Epoch [5/500] Batch [800/3682] LossD: 0.2919 LossG: 3.6623
# Epoch [5/500] Batch [900/3682] LossD: 0.1934 LossG: 4.3633
# Epoch [5/500] Batch [1000/3682] LossD: 0.3511 LossG: 9.1544
# Epoch [5/500] Batch [1100/3682] LossD: 0.1893 LossG: 6.1371
# Epoch [5/500] Batch [1200/3682] LossD: 0.1480 LossG: 5.7550
# Epoch [5/500] Batch [1300/3682] LossD: 0.0784 LossG: 5.0650
# Epoch [5/500] Batch [1400/3682] LossD: 0.0843 LossG: 6.9027
# Epoch [5/500] Batch [1500/3682] LossD: 0.0205 LossG: 5.4702
# Epoch [5/500] Batch [1600/3682] LossD: 0.2688 LossG: 5.7965
# Epoch [5/500] Batch [1700/3682] LossD: 2.6956 LossG: 0.8895
# Epoch [5/500] Batch [1800/3682] LossD: 0.0717 LossG: 5.0564
# Epoch [5/500] Batch [1900/3682] LossD: 0.6052 LossG: 1.8280
# Epoch [5/500] Batch [2000/3682] LossD: 0.2346 LossG: 4.9475
# Epoch [5/500] Batch [2100/3682] LossD: 0.1063 LossG: 5.8663
# Epoch [5/500] Batch [2200/3682] LossD: 0.0525 LossG: 4.5658
# Epoch [5/500] Batch [2300/3682] LossD: 0.0216 LossG: 5.7011
# Epoch [5/500] Batch [2400/3682] LossD: 0.2244 LossG: 5.7654
# Epoch [5/500] Batch [2500/3682] LossD: 0.0789 LossG: 5.5167
# Epoch [5/500] Batch [2600/3682] LossD: 0.0725 LossG: 5.6382
# Epoch [5/500] Batch [2700/3682] LossD: 0.0606 LossG: 4.9507
# Epoch [5/500] Batch [2800/3682] LossD: 0.0617 LossG: 5.3403
# Epoch [5/500] Batch [2900/3682] LossD: 5.1136 LossG: 6.6264
# Epoch [5/500] Batch [3000/3682] LossD: 0.1435 LossG: 4.5662
# Epoch [5/500] Batch [3100/3682] LossD: 0.1260 LossG: 5.8325
# Epoch [5/500] Batch [3200/3682] LossD: 0.1028 LossG: 5.9695
# Epoch [5/500] Batch [3300/3682] LossD: 0.3741 LossG: 4.3128
# Epoch [5/500] Batch [3400/3682] LossD: 0.0591 LossG: 6.2388
# Epoch [5/500] Batch [3500/3682] LossD: 0.0653 LossG: 5.2663
# Epoch [5/500] Batch [3600/3682] LossD: 0.0383 LossG: 5.0215
# Sample image saved: samples/epoch_5.png
# Epoch [6/500] Batch [0/3682] LossD: 0.2175 LossG: 2.5881
# Epoch [6/500] Batch [100/3682] LossD: 0.2047 LossG: 4.3269
# Epoch [6/500] Batch [200/3682] LossD: 0.0693 LossG: 6.6746
# Epoch [6/500] Batch [300/3682] LossD: 0.8503 LossG: 3.4526
# Epoch [6/500] Batch [400/3682] LossD: 0.0259 LossG: 5.6228
# Epoch [6/500] Batch [500/3682] LossD: 0.5693 LossG: 1.6961
# Epoch [6/500] Batch [600/3682] LossD: 0.1367 LossG: 4.8467
# Epoch [6/500] Batch [700/3682] LossD: 0.2401 LossG: 3.8936
# Epoch [6/500] Batch [800/3682] LossD: 0.0444 LossG: 5.2166
# Epoch [6/500] Batch [900/3682] LossD: 0.2841 LossG: 4.1805
# Epoch [6/500] Batch [1000/3682] LossD: 0.2336 LossG: 5.8129
# Epoch [6/500] Batch [1100/3682] LossD: 0.2258 LossG: 4.6653
# Epoch [6/500] Batch [1200/3682] LossD: 0.0740 LossG: 5.1810
# Epoch [6/500] Batch [1300/3682] LossD: 0.0485 LossG: 5.3710
# Epoch [6/500] Batch [1400/3682] LossD: 0.1658 LossG: 5.3384
# Epoch [6/500] Batch [1500/3682] LossD: 0.1922 LossG: 7.5395
# Epoch [6/500] Batch [1600/3682] LossD: 0.6866 LossG: 9.1607
# Epoch [6/500] Batch [1700/3682] LossD: 0.0902 LossG: 5.8302
# Epoch [6/500] Batch [1800/3682] LossD: 0.0407 LossG: 4.6212
# Epoch [6/500] Batch [1900/3682] LossD: 0.3915 LossG: 5.9581
# Epoch [6/500] Batch [2000/3682] LossD: 0.0968 LossG: 5.2360
# Epoch [6/500] Batch [2100/3682] LossD: 0.0459 LossG: 6.8128
# Epoch [6/500] Batch [2200/3682] LossD: 0.0714 LossG: 6.0571
# Epoch [6/500] Batch [2300/3682] LossD: 0.1624 LossG: 5.0200
# Epoch [6/500] Batch [2400/3682] LossD: 0.0855 LossG: 6.5164
# Epoch [6/500] Batch [2500/3682] LossD: 0.5903 LossG: 3.0246
# Epoch [6/500] Batch [2600/3682] LossD: 0.2399 LossG: 6.1917
# Epoch [6/500] Batch [2700/3682] LossD: 1.6381 LossG: 2.8202
# Epoch [6/500] Batch [2800/3682] LossD: 0.1230 LossG: 4.5706
# Epoch [6/500] Batch [2900/3682] LossD: 0.0600 LossG: 5.9084
# Epoch [6/500] Batch [3000/3682] LossD: 0.0875 LossG: 8.2343
# Epoch [6/500] Batch [3100/3682] LossD: 0.0505 LossG: 6.6845
# Epoch [6/500] Batch [3200/3682] LossD: 0.1614 LossG: 5.5878
# Epoch [6/500] Batch [3300/3682] LossD: 0.0896 LossG: 4.4605
# Epoch [6/500] Batch [3400/3682] LossD: 0.0268 LossG: 5.8067
# Epoch [6/500] Batch [3500/3682] LossD: 0.0623 LossG: 6.1974
# Epoch [6/500] Batch [3600/3682] LossD: 0.0596 LossG: 8.2855
# Sample image saved: samples/epoch_6.png
# Epoch [7/500] Batch [0/3682] LossD: 0.2056 LossG: 8.0775
# Epoch [7/500] Batch [100/3682] LossD: 0.3023 LossG: 5.3643
# Epoch [7/500] Batch [200/3682] LossD: 0.1231 LossG: 6.4367
# Epoch [7/500] Batch [300/3682] LossD: 0.2955 LossG: 3.2959
# Epoch [7/500] Batch [400/3682] LossD: 0.2592 LossG: 6.3576
# Epoch [7/500] Batch [500/3682] LossD: 0.1003 LossG: 4.6150
# Epoch [7/500] Batch [600/3682] LossD: 0.0333 LossG: 4.9511
# Epoch [7/500] Batch [700/3682] LossD: 0.0899 LossG: 7.0974
# Epoch [7/500] Batch [800/3682] LossD: 0.0189 LossG: 6.2264
# Epoch [7/500] Batch [900/3682] LossD: 0.0924 LossG: 5.0421
# Epoch [7/500] Batch [1000/3682] LossD: 0.0738 LossG: 6.3199
# Epoch [7/500] Batch [1100/3682] LossD: 0.0418 LossG: 6.1494
# Epoch [7/500] Batch [1200/3682] LossD: 0.0378 LossG: 6.0328
# Epoch [7/500] Batch [1300/3682] LossD: 0.2906 LossG: 3.3649
# Epoch [7/500] Batch [1400/3682] LossD: 0.1672 LossG: 3.3939
# Epoch [7/500] Batch [1500/3682] LossD: 0.8719 LossG: 5.0306
# Epoch [7/500] Batch [1600/3682] LossD: 0.2069 LossG: 7.8552
# Epoch [7/500] Batch [1700/3682] LossD: 0.0532 LossG: 5.2958
# Epoch [7/500] Batch [1800/3682] LossD: 0.0908 LossG: 5.2277
# Epoch [7/500] Batch [1900/3682] LossD: 0.2827 LossG: 5.7470
# Epoch [7/500] Batch [2000/3682] LossD: 0.0459 LossG: 5.6395
# Epoch [7/500] Batch [2100/3682] LossD: 0.2708 LossG: 5.4699
# Epoch [7/500] Batch [2200/3682] LossD: 0.1096 LossG: 5.3787
# Epoch [7/500] Batch [2300/3682] LossD: 0.0512 LossG: 5.4741
# Epoch [7/500] Batch [2400/3682] LossD: 0.3155 LossG: 7.1923
# Epoch [7/500] Batch [2500/3682] LossD: 0.0941 LossG: 5.6194
# Epoch [7/500] Batch [2600/3682] LossD: 0.0526 LossG: 5.9669
# Epoch [7/500] Batch [2700/3682] LossD: 0.0391 LossG: 5.5554
# Epoch [7/500] Batch [2800/3682] LossD: 0.0985 LossG: 5.1123
# Epoch [7/500] Batch [2900/3682] LossD: 0.0327 LossG: 6.1231
# Epoch [7/500] Batch [3000/3682] LossD: 0.1182 LossG: 5.2043
# Epoch [7/500] Batch [3100/3682] LossD: 0.0738 LossG: 4.7811
# Epoch [7/500] Batch [3200/3682] LossD: 0.1405 LossG: 5.3742
# Epoch [7/500] Batch [3300/3682] LossD: 0.0995 LossG: 6.6588
# Epoch [7/500] Batch [3400/3682] LossD: 0.0953 LossG: 4.9112
# Epoch [7/500] Batch [3500/3682] LossD: 0.2725 LossG: 3.3187
# Epoch [7/500] Batch [3600/3682] LossD: 0.0523 LossG: 5.4983
# Sample image saved: samples/epoch_7.png
# Epoch [8/500] Batch [0/3682] LossD: 0.0185 LossG: 5.3752
# Epoch [8/500] Batch [100/3682] LossD: 0.0444 LossG: 5.2759
# Epoch [8/500] Batch [200/3682] LossD: 0.0876 LossG: 4.9698
# Epoch [8/500] Batch [300/3682] LossD: 0.4914 LossG: 8.5987
# Epoch [8/500] Batch [400/3682] LossD: 0.0703 LossG: 5.2867
# Epoch [8/500] Batch [500/3682] LossD: 0.3751 LossG: 4.7891
# Epoch [8/500] Batch [600/3682] LossD: 0.0698 LossG: 6.3277
# Epoch [8/500] Batch [700/3682] LossD: 0.0131 LossG: 7.1518
# Epoch [8/500] Batch [800/3682] LossD: 0.0711 LossG: 4.5939
# Epoch [8/500] Batch [900/3682] LossD: 0.1115 LossG: 6.2505
# Epoch [8/500] Batch [1000/3682] LossD: 0.4115 LossG: 3.8018
# Epoch [8/500] Batch [1100/3682] LossD: 0.0515 LossG: 7.4259
# Epoch [8/500] Batch [1200/3682] LossD: 0.0294 LossG: 7.6243
# Epoch [8/500] Batch [1300/3682] LossD: 0.1180 LossG: 6.8282
# Epoch [8/500] Batch [1400/3682] LossD: 0.0299 LossG: 6.1385
# Epoch [8/500] Batch [1500/3682] LossD: 0.2365 LossG: 4.5971
# Epoch [8/500] Batch [1600/3682] LossD: 0.0467 LossG: 5.3962
# Epoch [8/500] Batch [1700/3682] LossD: 0.1624 LossG: 7.0870
# Epoch [8/500] Batch [1800/3682] LossD: 0.0186 LossG: 6.1138
# Epoch [8/500] Batch [1900/3682] LossD: 0.0349 LossG: 6.3554
# Epoch [8/500] Batch [2000/3682] LossD: 0.0631 LossG: 5.7678
# Epoch [8/500] Batch [2100/3682] LossD: 0.0653 LossG: 5.3556
# Epoch [8/500] Batch [2200/3682] LossD: 0.0357 LossG: 6.0805
# Epoch [8/500] Batch [2300/3682] LossD: 0.0166 LossG: 6.1715
# Epoch [8/500] Batch [2400/3682] LossD: 0.3126 LossG: 4.4438
# Epoch [8/500] Batch [2500/3682] LossD: 0.0832 LossG: 4.5231
# Epoch [8/500] Batch [2600/3682] LossD: 5.6898 LossG: 0.1166
# Epoch [8/500] Batch [2700/3682] LossD: 1.0396 LossG: 2.8984
# Epoch [8/500] Batch [2800/3682] LossD: 0.0835 LossG: 5.2956
# Epoch [8/500] Batch [2900/3682] LossD: 0.0541 LossG: 5.8856
# Epoch [8/500] Batch [3000/3682] LossD: 0.1070 LossG: 4.7422
# Epoch [8/500] Batch [3100/3682] LossD: 0.0591 LossG: 5.8258
# Epoch [8/500] Batch [3200/3682] LossD: 0.1299 LossG: 4.8249
# Epoch [8/500] Batch [3300/3682] LossD: 0.0442 LossG: 5.5850
# Epoch [8/500] Batch [3400/3682] LossD: 0.0333 LossG: 6.0986
# Epoch [8/500] Batch [3500/3682] LossD: 0.0486 LossG: 6.0810
# Epoch [8/500] Batch [3600/3682] LossD: 0.0666 LossG: 6.9910
# Sample image saved: samples/epoch_8.png
# Epoch [9/500] Batch [0/3682] LossD: 0.0403 LossG: 5.3852
# Epoch [9/500] Batch [100/3682] LossD: 0.2251 LossG: 4.4727
# Epoch [9/500] Batch [200/3682] LossD: 0.1041 LossG: 7.1816
# Epoch [9/500] Batch [300/3682] LossD: 0.0377 LossG: 6.1296
# Epoch [9/500] Batch [400/3682] LossD: 1.0852 LossG: 4.9827
# Epoch [9/500] Batch [500/3682] LossD: 0.0350 LossG: 6.1011
# Epoch [9/500] Batch [600/3682] LossD: 0.0150 LossG: 7.4188
# Epoch [9/500] Batch [700/3682] LossD: 0.0362 LossG: 6.3339
# Epoch [9/500] Batch [800/3682] LossD: 0.0399 LossG: 6.4881
# Epoch [9/500] Batch [900/3682] LossD: 0.0866 LossG: 5.6831
# Epoch [9/500] Batch [1000/3682] LossD: 0.0978 LossG: 6.1920
# Epoch [9/500] Batch [1100/3682] LossD: 0.1975 LossG: 2.7930
# Epoch [9/500] Batch [1200/3682] LossD: 0.0186 LossG: 6.2465
# Epoch [9/500] Batch [1300/3682] LossD: 0.0295 LossG: 5.6679
# Epoch [9/500] Batch [1400/3682] LossD: 0.0244 LossG: 5.8019
# Epoch [9/500] Batch [1500/3682] LossD: 0.0121 LossG: 6.4084
# Epoch [9/500] Batch [1600/3682] LossD: 0.0260 LossG: 6.0902
# Epoch [9/500] Batch [1700/3682] LossD: 0.1582 LossG: 6.6181
# Epoch [9/500] Batch [1800/3682] LossD: 0.0397 LossG: 5.7254
# Epoch [9/500] Batch [1900/3682] LossD: 0.0310 LossG: 5.8369
# Epoch [9/500] Batch [2000/3682] LossD: 0.0223 LossG: 5.0577
# Epoch [9/500] Batch [2100/3682] LossD: 0.1366 LossG: 6.2935
# Epoch [9/500] Batch [2200/3682] LossD: 0.1927 LossG: 6.4891
# Epoch [9/500] Batch [2300/3682] LossD: 0.2527 LossG: 4.8704
# Epoch [9/500] Batch [2400/3682] LossD: 0.0922 LossG: 4.9882
# Epoch [9/500] Batch [2500/3682] LossD: 0.0815 LossG: 4.5653
# Epoch [9/500] Batch [2600/3682] LossD: 0.5967 LossG: 2.9073
# Epoch [9/500] Batch [2700/3682] LossD: 0.1364 LossG: 5.5514
# Epoch [9/500] Batch [2800/3682] LossD: 0.1495 LossG: 5.1791
# Epoch [9/500] Batch [2900/3682] LossD: 0.0630 LossG: 6.8604
# Epoch [9/500] Batch [3000/3682] LossD: 0.0824 LossG: 6.9125
# Epoch [9/500] Batch [3100/3682] LossD: 0.0114 LossG: 7.0852
# Epoch [9/500] Batch [3200/3682] LossD: 0.0488 LossG: 5.6167
# Epoch [9/500] Batch [3300/3682] LossD: 0.4465 LossG: 4.2779
# Epoch [9/500] Batch [3400/3682] LossD: 0.0376 LossG: 6.0843
# Epoch [9/500] Batch [3500/3682] LossD: 0.1960 LossG: 7.7576
# Epoch [9/500] Batch [3600/3682] LossD: 0.1592 LossG: 5.0862
# Sample image saved: samples/epoch_9.png
# Epoch [10/500] Batch [0/3682] LossD: 0.1349 LossG: 8.5287
# Epoch [10/500] Batch [100/3682] LossD: 0.0263 LossG: 7.3795
# Epoch [10/500] Batch [200/3682] LossD: 0.0497 LossG: 5.3588
# Epoch [10/500] Batch [300/3682] LossD: 0.0602 LossG: 5.3608
# Epoch [10/500] Batch [400/3682] LossD: 0.0509 LossG: 6.1998
# Epoch [10/500] Batch [500/3682] LossD: 0.0484 LossG: 5.9595
# Epoch [10/500] Batch [600/3682] LossD: 0.1317 LossG: 4.4124
# Epoch [10/500] Batch [700/3682] LossD: 0.0734 LossG: 5.2290
# Epoch [10/500] Batch [800/3682] LossD: 0.0723 LossG: 5.1020
# Epoch [10/500] Batch [900/3682] LossD: 0.0232 LossG: 8.0094
# Epoch [10/500] Batch [1000/3682] LossD: 0.0105 LossG: 6.3924
# Epoch [10/500] Batch [1100/3682] LossD: 0.0192 LossG: 7.0369
# Epoch [10/500] Batch [1200/3682] LossD: 0.0310 LossG: 8.7281
# Epoch [10/500] Batch [1300/3682] LossD: 0.0538 LossG: 5.9540
# Epoch [10/500] Batch [1400/3682] LossD: 0.0876 LossG: 5.0668
# Epoch [10/500] Batch [1500/3682] LossD: 0.3377 LossG: 7.5081
# Epoch [10/500] Batch [1600/3682] LossD: 0.0513 LossG: 5.6975
# Epoch [10/500] Batch [1700/3682] LossD: 0.0528 LossG: 5.5306
# Epoch [10/500] Batch [1800/3682] LossD: 0.1334 LossG: 6.7855
# Epoch [10/500] Batch [1900/3682] LossD: 0.0721 LossG: 5.2540
# Epoch [10/500] Batch [2000/3682] LossD: 0.2640 LossG: 7.2998
# Epoch [10/500] Batch [2100/3682] LossD: 0.0158 LossG: 6.2511
# Epoch [10/500] Batch [2200/3682] LossD: 0.1791 LossG: 8.9296
# Epoch [10/500] Batch [2300/3682] LossD: 0.0640 LossG: 7.7522
# Epoch [10/500] Batch [2400/3682] LossD: 0.3931 LossG: 5.4167
# Epoch [10/500] Batch [2500/3682] LossD: 0.1191 LossG: 4.3064
# Epoch [10/500] Batch [2600/3682] LossD: 0.0411 LossG: 6.2134
# Epoch [10/500] Batch [2700/3682] LossD: 0.0500 LossG: 5.7548
# Epoch [10/500] Batch [2800/3682] LossD: 0.0836 LossG: 6.5555
# Epoch [10/500] Batch [2900/3682] LossD: 0.1196 LossG: 6.2867
# Epoch [10/500] Batch [3000/3682] LossD: 0.0276 LossG: 5.3136
# Epoch [10/500] Batch [3100/3682] LossD: 0.0625 LossG: 6.1288
# Epoch [10/500] Batch [3200/3682] LossD: 0.0516 LossG: 4.5904
# Epoch [10/500] Batch [3300/3682] LossD: 0.0435 LossG: 7.0101
# Epoch [10/500] Batch [3400/3682] LossD: 0.0851 LossG: 5.1109
# Epoch [10/500] Batch [3500/3682] LossD: 0.1024 LossG: 6.2676
# Epoch [10/500] Batch [3600/3682] LossD: 0.0312 LossG: 6.2108
# Sample image saved: samples/epoch_10.png
# Epoch [11/500] Batch [0/3682] LossD: 0.0828 LossG: 6.4809
# Epoch [11/500] Batch [100/3682] LossD: 0.2654 LossG: 4.0116
# Epoch [11/500] Batch [200/3682] LossD: 0.0658 LossG: 4.5595
# Epoch [11/500] Batch [300/3682] LossD: 0.0492 LossG: 6.0417
# Epoch [11/500] Batch [400/3682] LossD: 0.0809 LossG: 6.9013
# Epoch [11/500] Batch [500/3682] LossD: 0.0274 LossG: 6.7323
# Epoch [11/500] Batch [600/3682] LossD: 0.0229 LossG: 6.1908
# Epoch [11/500] Batch [700/3682] LossD: 0.0315 LossG: 7.5882
# Epoch [11/500] Batch [800/3682] LossD: 0.1121 LossG: 3.8950
# Epoch [11/500] Batch [900/3682] LossD: 0.1058 LossG: 7.6638
# Epoch [11/500] Batch [1000/3682] LossD: 0.0323 LossG: 5.2687
# Epoch [11/500] Batch [1100/3682] LossD: 0.3160 LossG: 5.0698
# Epoch [11/500] Batch [1200/3682] LossD: 0.0368 LossG: 5.3200
# Epoch [11/500] Batch [1300/3682] LossD: 0.1095 LossG: 6.6848
# Epoch [11/500] Batch [1400/3682] LossD: 0.0405 LossG: 5.9051
# Epoch [11/500] Batch [1500/3682] LossD: 0.0488 LossG: 5.3053
# Epoch [11/500] Batch [1600/3682] LossD: 0.0980 LossG: 5.3664
# Epoch [11/500] Batch [1700/3682] LossD: 0.0287 LossG: 5.9565
# Epoch [11/500] Batch [1800/3682] LossD: 0.0536 LossG: 6.3686
# Epoch [11/500] Batch [1900/3682] LossD: 0.0388 LossG: 5.7754
# Epoch [11/500] Batch [2000/3682] LossD: 0.0545 LossG: 4.5146
# Epoch [11/500] Batch [2100/3682] LossD: 0.0221 LossG: 7.4754
# Epoch [11/500] Batch [2200/3682] LossD: 0.0391 LossG: 5.6838
# Epoch [11/500] Batch [2300/3682] LossD: 0.0537 LossG: 5.6194
# Epoch [11/500] Batch [2400/3682] LossD: 0.0198 LossG: 9.9798
# Epoch [11/500] Batch [2500/3682] LossD: 0.0756 LossG: 4.4101
# Epoch [11/500] Batch [2600/3682] LossD: 0.1179 LossG: 5.9298
# Epoch [11/500] Batch [2700/3682] LossD: 0.1193 LossG: 5.1278
# Epoch [11/500] Batch [2800/3682] LossD: 0.0517 LossG: 4.7931
# Epoch [11/500] Batch [2900/3682] LossD: 0.0599 LossG: 6.3817
# Epoch [11/500] Batch [3000/3682] LossD: 0.0096 LossG: 6.7376
# Epoch [11/500] Batch [3100/3682] LossD: 0.0465 LossG: 7.2988
# Epoch [11/500] Batch [3200/3682] LossD: 0.1815 LossG: 9.3509
# Epoch [11/500] Batch [3300/3682] LossD: 0.0418 LossG: 6.2977
# Epoch [11/500] Batch [3400/3682] LossD: 0.0972 LossG: 3.4308
# Epoch [11/500] Batch [3500/3682] LossD: 0.0516 LossG: 5.8967
# Epoch [11/500] Batch [3600/3682] LossD: 0.1127 LossG: 5.3140
# Sample image saved: samples/epoch_11.png
# Epoch [12/500] Batch [0/3682] LossD: 1.3644 LossG: 0.9440
# Epoch [12/500] Batch [100/3682] LossD: 0.0521 LossG: 7.2610
# Epoch [12/500] Batch [200/3682] LossD: 0.1805 LossG: 4.1558
# Epoch [12/500] Batch [300/3682] LossD: 0.0819 LossG: 6.3635
# Epoch [12/500] Batch [400/3682] LossD: 0.0226 LossG: 7.1262
# Epoch [12/500] Batch [500/3682] LossD: 0.0964 LossG: 5.7789
# Epoch [12/500] Batch [600/3682] LossD: 0.0659 LossG: 6.2716
# Epoch [12/500] Batch [700/3682] LossD: 0.0191 LossG: 6.4397
# Epoch [12/500] Batch [800/3682] LossD: 0.0144 LossG: 7.9743
# Epoch [12/500] Batch [900/3682] LossD: 0.0160 LossG: 6.4540
# Epoch [12/500] Batch [1000/3682] LossD: 1.2800 LossG: 18.5827
# Epoch [12/500] Batch [1100/3682] LossD: 0.0415 LossG: 6.1778
# Epoch [12/500] Batch [1200/3682] LossD: 0.0492 LossG: 5.8669
# Epoch [12/500] Batch [1300/3682] LossD: 0.1268 LossG: 8.2198
# Epoch [12/500] Batch [1400/3682] LossD: 0.0207 LossG: 6.2928
# Epoch [12/500] Batch [1500/3682] LossD: 0.0304 LossG: 5.6533
# Epoch [12/500] Batch [1600/3682] LossD: 0.0264 LossG: 5.3779
# Epoch [12/500] Batch [1700/3682] LossD: 0.0254 LossG: 6.4844
# Epoch [12/500] Batch [1800/3682] LossD: 0.0720 LossG: 6.1317
# Epoch [12/500] Batch [1900/3682] LossD: 0.0567 LossG: 7.2810
# Epoch [12/500] Batch [2000/3682] LossD: 0.3406 LossG: 4.3635
# Epoch [12/500] Batch [2100/3682] LossD: 0.1022 LossG: 6.2129
# Epoch [12/500] Batch [2200/3682] LossD: 0.0779 LossG: 6.5553
# Epoch [12/500] Batch [2300/3682] LossD: 0.1436 LossG: 5.7099
# Epoch [12/500] Batch [2400/3682] LossD: 0.1017 LossG: 5.4237
# Epoch [12/500] Batch [2500/3682] LossD: 0.0723 LossG: 5.9956
# Epoch [12/500] Batch [2600/3682] LossD: 0.0381 LossG: 6.1229
# Epoch [12/500] Batch [2700/3682] LossD: 0.0138 LossG: 6.2001
# Epoch [12/500] Batch [2800/3682] LossD: 0.0847 LossG: 4.9798
# Epoch [12/500] Batch [2900/3682] LossD: 0.0872 LossG: 6.1362
# Epoch [12/500] Batch [3000/3682] LossD: 0.0333 LossG: 7.3711
# Epoch [12/500] Batch [3100/3682] LossD: 0.0105 LossG: 7.5968
# Epoch [12/500] Batch [3200/3682] LossD: 0.0277 LossG: 6.6108
# Epoch [12/500] Batch [3300/3682] LossD: 0.5399 LossG: 15.7526
# Epoch [12/500] Batch [3400/3682] LossD: 0.0421 LossG: 7.0368
# Epoch [12/500] Batch [3500/3682] LossD: 0.3140 LossG: 3.8852
# Epoch [12/500] Batch [3600/3682] LossD: 0.0180 LossG: 9.0066
# Sample image saved: samples/epoch_12.png
# Epoch [13/500] Batch [0/3682] LossD: 0.2504 LossG: 13.5541
# Epoch [13/500] Batch [100/3682] LossD: 2.0720 LossG: 1.6079
# Epoch [13/500] Batch [200/3682] LossD: 0.0371 LossG: 5.7879
# Epoch [13/500] Batch [300/3682] LossD: 0.2775 LossG: 4.7374
# Epoch [13/500] Batch [400/3682] LossD: 0.0265 LossG: 7.0805
# Epoch [13/500] Batch [500/3682] LossD: 0.0245 LossG: 8.3861
# Epoch [13/500] Batch [600/3682] LossD: 0.0936 LossG: 5.3942
# Epoch [13/500] Batch [700/3682] LossD: 0.0944 LossG: 7.2154
# Epoch [13/500] Batch [800/3682] LossD: 0.0070 LossG: 6.5850
# Epoch [13/500] Batch [900/3682] LossD: 0.0104 LossG: 6.9167
# Epoch [13/500] Batch [1000/3682] LossD: 0.0799 LossG: 5.3490
# Epoch [13/500] Batch [1100/3682] LossD: 0.1056 LossG: 4.9658
# Epoch [13/500] Batch [1200/3682] LossD: 0.1864 LossG: 5.7552
# Epoch [13/500] Batch [1300/3682] LossD: 0.0243 LossG: 6.1935
# Epoch [13/500] Batch [1400/3682] LossD: 0.0086 LossG: 7.4169
# Epoch [13/500] Batch [1500/3682] LossD: 0.0262 LossG: 6.9690
# Epoch [13/500] Batch [1600/3682] LossD: 2.3196 LossG: 3.5390
# Epoch [13/500] Batch [1700/3682] LossD: 0.0147 LossG: 6.0541
# Epoch [13/500] Batch [1800/3682] LossD: 0.0335 LossG: 7.2644
# Epoch [13/500] Batch [1900/3682] LossD: 0.0409 LossG: 6.5914
# Epoch [13/500] Batch [2000/3682] LossD: 0.0144 LossG: 7.2445
# Epoch [13/500] Batch [2100/3682] LossD: 0.1342 LossG: 3.3370
# Epoch [13/500] Batch [2200/3682] LossD: 0.2671 LossG: 8.1819
# Epoch [13/500] Batch [2300/3682] LossD: 0.0640 LossG: 6.2294
# Epoch [13/500] Batch [2400/3682] LossD: 0.0098 LossG: 6.7719
# Epoch [13/500] Batch [2500/3682] LossD: 0.1037 LossG: 5.8821
# Epoch [13/500] Batch [2600/3682] LossD: 0.0102 LossG: 6.3778
# Epoch [13/500] Batch [2700/3682] LossD: 0.0217 LossG: 6.3311
# Epoch [13/500] Batch [2800/3682] LossD: 0.3217 LossG: 11.4386
# Epoch [13/500] Batch [2900/3682] LossD: 0.0350 LossG: 6.9693
# Epoch [13/500] Batch [3000/3682] LossD: 0.0115 LossG: 7.4697
# Epoch [13/500] Batch [3100/3682] LossD: 0.4402 LossG: 3.2396
# Epoch [13/500] Batch [3200/3682] LossD: 0.0215 LossG: 6.1994
# Epoch [13/500] Batch [3300/3682] LossD: 0.0233 LossG: 7.2799
# Epoch [13/500] Batch [3400/3682] LossD: 9.6243 LossG: 0.4445
# Epoch [13/500] Batch [3500/3682] LossD: 0.0310 LossG: 6.7133
# Epoch [13/500] Batch [3600/3682] LossD: 0.0517 LossG: 5.5001
# Sample image saved: samples/epoch_13.png
# Epoch [14/500] Batch [0/3682] LossD: 0.0954 LossG: 8.1771
# Epoch [14/500] Batch [100/3682] LossD: 0.1008 LossG: 7.9136
# Epoch [14/500] Batch [200/3682] LossD: 0.0767 LossG: 6.3875
# Epoch [14/500] Batch [300/3682] LossD: 0.0169 LossG: 10.3054
# Epoch [14/500] Batch [400/3682] LossD: 0.0126 LossG: 6.2819
# Epoch [14/500] Batch [500/3682] LossD: 0.3707 LossG: 5.2625
# Epoch [14/500] Batch [600/3682] LossD: 0.0419 LossG: 7.4032
# Epoch [14/500] Batch [700/3682] LossD: 0.0902 LossG: 8.1722
# Epoch [14/500] Batch [800/3682] LossD: 0.0105 LossG: 7.5182
# Epoch [14/500] Batch [900/3682] LossD: 0.1043 LossG: 4.3489
# Epoch [14/500] Batch [1000/3682] LossD: 0.0484 LossG: 6.9076
# Epoch [14/500] Batch [1100/3682] LossD: 0.0061 LossG: 9.2060
# Epoch [14/500] Batch [1200/3682] LossD: 0.0096 LossG: 7.8859
# Epoch [14/500] Batch [1300/3682] LossD: 0.0365 LossG: 8.3221
# Epoch [14/500] Batch [1400/3682] LossD: 0.0445 LossG: 4.6681
# Epoch [14/500] Batch [1500/3682] LossD: 0.0594 LossG: 6.6117
# Epoch [14/500] Batch [1600/3682] LossD: 0.0058 LossG: 6.4532
# Epoch [14/500] Batch [1700/3682] LossD: 0.0141 LossG: 6.7818
# Epoch [14/500] Batch [1800/3682] LossD: 0.0495 LossG: 5.5747
# Epoch [14/500] Batch [1900/3682] LossD: 0.0380 LossG: 5.6066
# Epoch [14/500] Batch [2000/3682] LossD: 0.0777 LossG: 6.1108
# Epoch [14/500] Batch [2100/3682] LossD: 0.0558 LossG: 5.9555
# Epoch [14/500] Batch [2200/3682] LossD: 0.0381 LossG: 6.3977
# Epoch [14/500] Batch [2300/3682] LossD: 0.0327 LossG: 5.9685
# Epoch [14/500] Batch [2400/3682] LossD: 0.0385 LossG: 8.6822
# Epoch [14/500] Batch [2500/3682] LossD: 0.1471 LossG: 4.2628
# Epoch [14/500] Batch [2600/3682] LossD: 0.2184 LossG: 6.4447
# Epoch [14/500] Batch [2700/3682] LossD: 0.0233 LossG: 6.2015
# Epoch [14/500] Batch [2800/3682] LossD: 0.1419 LossG: 5.5397
# Epoch [14/500] Batch [2900/3682] LossD: 0.0426 LossG: 6.3224
# Epoch [14/500] Batch [3000/3682] LossD: 0.1131 LossG: 5.6485
# Epoch [14/500] Batch [3100/3682] LossD: 0.0283 LossG: 5.9647
# Epoch [14/500] Batch [3200/3682] LossD: 0.1079 LossG: 3.2844
# Epoch [14/500] Batch [3300/3682] LossD: 0.0777 LossG: 7.8552
# Epoch [14/500] Batch [3400/3682] LossD: 0.0362 LossG: 6.0934
# Epoch [14/500] Batch [3500/3682] LossD: 0.0288 LossG: 5.5075
# Epoch [14/500] Batch [3600/3682] LossD: 0.0332 LossG: 5.7081
# Sample image saved: samples/epoch_14.png
# Epoch [15/500] Batch [0/3682] LossD: 0.0625 LossG: 5.5073
# Epoch [15/500] Batch [100/3682] LossD: 0.0393 LossG: 6.0494
# Epoch [15/500] Batch [200/3682] LossD: 0.1047 LossG: 5.7508
# Epoch [15/500] Batch [300/3682] LossD: 0.0481 LossG: 6.6485
# Epoch [15/500] Batch [400/3682] LossD: 0.0250 LossG: 6.7761
# Epoch [15/500] Batch [500/3682] LossD: 0.0358 LossG: 6.8862
# Epoch [15/500] Batch [600/3682] LossD: 0.0625 LossG: 5.4254
# Epoch [15/500] Batch [700/3682] LossD: 0.0349 LossG: 6.8709
# Epoch [15/500] Batch [800/3682] LossD: 0.1347 LossG: 7.4781
# Epoch [15/500] Batch [900/3682] LossD: 0.0256 LossG: 6.1355
# Epoch [15/500] Batch [1000/3682] LossD: 0.0332 LossG: 6.1735
# Epoch [15/500] Batch [1100/3682] LossD: 0.0616 LossG: 5.1887
# Epoch [15/500] Batch [1200/3682] LossD: 0.0446 LossG: 4.5645
# Epoch [15/500] Batch [1300/3682] LossD: 0.0126 LossG: 7.3552
# Epoch [15/500] Batch [1400/3682] LossD: 0.0198 LossG: 6.7506
# Epoch [15/500] Batch [1500/3682] LossD: 0.0491 LossG: 5.2090
# Epoch [15/500] Batch [1600/3682] LossD: 0.0168 LossG: 5.7899
# Epoch [15/500] Batch [1700/3682] LossD: 0.0337 LossG: 6.4683
# Epoch [15/500] Batch [1800/3682] LossD: 0.0230 LossG: 5.8494
# Epoch [15/500] Batch [1900/3682] LossD: 0.0116 LossG: 7.0262
# Epoch [15/500] Batch [2000/3682] LossD: 0.0033 LossG: 8.2420
# Epoch [15/500] Batch [2100/3682] LossD: 0.0836 LossG: 7.9409
# Epoch [15/500] Batch [2200/3682] LossD: 0.0822 LossG: 6.7647
# Epoch [15/500] Batch [2300/3682] LossD: 0.0289 LossG: 6.3873
# Epoch [15/500] Batch [2400/3682] LossD: 0.0684 LossG: 5.9033
# Epoch [15/500] Batch [2500/3682] LossD: 0.0730 LossG: 5.4531
# Epoch [15/500] Batch [2600/3682] LossD: 0.1058 LossG: 7.2175
# Epoch [15/500] Batch [2700/3682] LossD: 0.0285 LossG: 6.2577
# Epoch [15/500] Batch [2800/3682] LossD: 0.1001 LossG: 8.1224
# Epoch [15/500] Batch [2900/3682] LossD: 0.0385 LossG: 6.0087
# Epoch [15/500] Batch [3000/3682] LossD: 0.0394 LossG: 5.9632
# Epoch [15/500] Batch [3100/3682] LossD: 0.0174 LossG: 5.5658
# Epoch [15/500] Batch [3200/3682] LossD: 0.0186 LossG: 6.6618
# Epoch [15/500] Batch [3300/3682] LossD: 0.0725 LossG: 5.8573
# Epoch [15/500] Batch [3400/3682] LossD: 0.0125 LossG: 6.6640
# Epoch [15/500] Batch [3500/3682] LossD: 0.0174 LossG: 5.7452
# Epoch [15/500] Batch [3600/3682] LossD: 0.0240 LossG: 7.0276
# Sample image saved: samples/epoch_15.png
# Epoch [16/500] Batch [0/3682] LossD: 0.0689 LossG: 7.3277
# Epoch [16/500] Batch [100/3682] LossD: 0.0437 LossG: 6.0374
# Epoch [16/500] Batch [200/3682] LossD: 0.0617 LossG: 6.6625
# Epoch [16/500] Batch [300/3682] LossD: 0.0180 LossG: 7.6246
# Epoch [16/500] Batch [400/3682] LossD: 1.3358 LossG: 21.6961
# Epoch [16/500] Batch [500/3682] LossD: 0.0509 LossG: 6.6972
# Epoch [16/500] Batch [600/3682] LossD: 0.1239 LossG: 6.7054
# Epoch [16/500] Batch [700/3682] LossD: 0.0512 LossG: 6.7028
# Epoch [16/500] Batch [800/3682] LossD: 0.0953 LossG: 7.5988
# Epoch [16/500] Batch [900/3682] LossD: 0.0153 LossG: 8.2337
# Epoch [16/500] Batch [1000/3682] LossD: 0.0298 LossG: 6.4750
# Epoch [16/500] Batch [1100/3682] LossD: 0.0197 LossG: 6.9721
# Epoch [16/500] Batch [1200/3682] LossD: 0.1239 LossG: 5.6804
# Epoch [16/500] Batch [1300/3682] LossD: 8.3394 LossG: 3.0274
# Epoch [16/500] Batch [1400/3682] LossD: 0.0170 LossG: 6.2780
# Epoch [16/500] Batch [1500/3682] LossD: 0.0218 LossG: 6.7566
# Epoch [16/500] Batch [1600/3682] LossD: 0.0236 LossG: 6.1749
# Epoch [16/500] Batch [1700/3682] LossD: 0.0280 LossG: 6.3470
# Epoch [16/500] Batch [1800/3682] LossD: 0.0479 LossG: 5.6876
# Epoch [16/500] Batch [1900/3682] LossD: 0.2307 LossG: 4.4553
# Epoch [16/500] Batch [2000/3682] LossD: 0.0225 LossG: 6.4306
# Epoch [16/500] Batch [2100/3682] LossD: 0.0262 LossG: 6.2074
# Epoch [16/500] Batch [2200/3682] LossD: 0.1790 LossG: 5.9736
# Epoch [16/500] Batch [2300/3682] LossD: 0.2729 LossG: 3.8532
# Epoch [16/500] Batch [2400/3682] LossD: 0.0734 LossG: 7.4281
# Epoch [16/500] Batch [2500/3682] LossD: 0.0305 LossG: 6.5111
# Epoch [16/500] Batch [2600/3682] LossD: 0.0401 LossG: 6.2332
# Epoch [16/500] Batch [2700/3682] LossD: 0.0523 LossG: 5.1451
# Epoch [16/500] Batch [2800/3682] LossD: 0.0184 LossG: 5.3282
# Epoch [16/500] Batch [2900/3682] LossD: 0.0047 LossG: 7.7504
# Epoch [16/500] Batch [3000/3682] LossD: 0.2140 LossG: 7.0507
# Epoch [16/500] Batch [3100/3682] LossD: 0.3731 LossG: 10.2321
# Epoch [16/500] Batch [3200/3682] LossD: 0.1457 LossG: 5.7822
# Epoch [16/500] Batch [3300/3682] LossD: 0.0824 LossG: 7.0848
# Epoch [16/500] Batch [3400/3682] LossD: 0.0619 LossG: 8.1376
# Epoch [16/500] Batch [3500/3682] LossD: 0.0837 LossG: 4.7569
# Epoch [16/500] Batch [3600/3682] LossD: 0.0633 LossG: 5.8567
# Sample image saved: samples/epoch_16.png
# Epoch [17/500] Batch [0/3682] LossD: 0.0047 LossG: 6.6126
# Epoch [17/500] Batch [100/3682] LossD: 0.0142 LossG: 6.4636
# Epoch [17/500] Batch [200/3682] LossD: 0.0547 LossG: 5.0095
# Epoch [17/500] Batch [300/3682] LossD: 0.0350 LossG: 6.9780
# Epoch [17/500] Batch [400/3682] LossD: 0.0560 LossG: 6.4782
# Epoch [17/500] Batch [500/3682] LossD: 0.1146 LossG: 8.2226
# Epoch [17/500] Batch [600/3682] LossD: 0.0109 LossG: 8.8377
# Epoch [17/500] Batch [700/3682] LossD: 0.1049 LossG: 5.6193
# Epoch [17/500] Batch [800/3682] LossD: 0.0477 LossG: 7.4157
# Epoch [17/500] Batch [900/3682] LossD: 0.0104 LossG: 7.0186
# Epoch [17/500] Batch [1000/3682] LossD: 0.1482 LossG: 3.6164
# Epoch [17/500] Batch [1100/3682] LossD: 0.0040 LossG: 9.4856
# Epoch [17/500] Batch [1200/3682] LossD: 0.0198 LossG: 6.1873
# Epoch [17/500] Batch [1300/3682] LossD: 0.0307 LossG: 6.6857
# Epoch [17/500] Batch [1400/3682] LossD: 0.0587 LossG: 5.6520
# Epoch [17/500] Batch [1500/3682] LossD: 0.0266 LossG: 6.5791
# Epoch [17/500] Batch [1600/3682] LossD: 0.0648 LossG: 5.2023
# Epoch [17/500] Batch [1700/3682] LossD: 0.0044 LossG: 7.3490
# Epoch [17/500] Batch [1800/3682] LossD: 0.0391 LossG: 6.7506
# Epoch [17/500] Batch [1900/3682] LossD: 0.0245 LossG: 6.2803
# Epoch [17/500] Batch [2000/3682] LossD: 0.3686 LossG: 5.9323
# Epoch [17/500] Batch [2100/3682] LossD: 0.3493 LossG: 9.2548
# Epoch [17/500] Batch [2200/3682] LossD: 0.1464 LossG: 7.8863
# Epoch [17/500] Batch [2300/3682] LossD: 0.0864 LossG: 5.3076
# Epoch [17/500] Batch [2400/3682] LossD: 0.0279 LossG: 6.7682
# Epoch [17/500] Batch [2500/3682] LossD: 0.0118 LossG: 8.2117
# Epoch [17/500] Batch [2600/3682] LossD: 0.0174 LossG: 6.5129
# Epoch [17/500] Batch [2700/3682] LossD: 0.0101 LossG: 7.3759
# Epoch [17/500] Batch [2800/3682] LossD: 0.0182 LossG: 7.3944
# Epoch [17/500] Batch [2900/3682] LossD: 0.0557 LossG: 7.0932
# Epoch [17/500] Batch [3000/3682] LossD: 2.0963 LossG: 4.2391
# Epoch [17/500] Batch [3100/3682] LossD: 0.0832 LossG: 5.7371
# Epoch [17/500] Batch [3200/3682] LossD: 0.0253 LossG: 6.1972
# Epoch [17/500] Batch [3300/3682] LossD: 0.1410 LossG: 3.5693
# Epoch [17/500] Batch [3400/3682] LossD: 0.0097 LossG: 7.1078
# Epoch [17/500] Batch [3500/3682] LossD: 0.1201 LossG: 3.3166
# Epoch [17/500] Batch [3600/3682] LossD: 0.1856 LossG: 6.0691
# Sample image saved: samples/epoch_17.png
# Epoch [18/500] Batch [0/3682] LossD: 0.0571 LossG: 5.7019
# Epoch [18/500] Batch [100/3682] LossD: 0.0126 LossG: 5.8201
# Epoch [18/500] Batch [200/3682] LossD: 0.0101 LossG: 7.5757
# Epoch [18/500] Batch [300/3682] LossD: 0.2801 LossG: 6.9376
# Epoch [18/500] Batch [400/3682] LossD: 0.0216 LossG: 6.2415
# Epoch [18/500] Batch [500/3682] LossD: 0.0409 LossG: 6.5156
# Epoch [18/500] Batch [600/3682] LossD: 0.0597 LossG: 7.1120
# Epoch [18/500] Batch [700/3682] LossD: 0.0370 LossG: 7.2622
# Epoch [18/500] Batch [800/3682] LossD: 0.0184 LossG: 6.7042
# Epoch [18/500] Batch [900/3682] LossD: 0.5446 LossG: 4.2510
# Epoch [18/500] Batch [1000/3682] LossD: 0.0133 LossG: 6.5653
# Epoch [18/500] Batch [1100/3682] LossD: 0.0304 LossG: 7.1313
# Epoch [18/500] Batch [1200/3682] LossD: 0.0241 LossG: 7.2885
# Epoch [18/500] Batch [1300/3682] LossD: 0.0124 LossG: 6.5255
# Epoch [18/500] Batch [1400/3682] LossD: 0.0355 LossG: 6.1428
# Epoch [18/500] Batch [1500/3682] LossD: 0.0086 LossG: 6.3814
# Epoch [18/500] Batch [1600/3682] LossD: 0.0349 LossG: 6.0940
# Epoch [18/500] Batch [1700/3682] LossD: 7.1399 LossG: 25.2227
# Epoch [18/500] Batch [1800/3682] LossD: 0.0636 LossG: 5.1327
# Epoch [18/500] Batch [1900/3682] LossD: 0.1157 LossG: 8.2504
# Epoch [18/500] Batch [2000/3682] LossD: 0.0339 LossG: 6.7950
# Epoch [18/500] Batch [2100/3682] LossD: 0.0564 LossG: 6.1597
# Epoch [18/500] Batch [2200/3682] LossD: 0.0472 LossG: 5.8064
# Epoch [18/500] Batch [2300/3682] LossD: 0.1466 LossG: 3.1642
# Epoch [18/500] Batch [2400/3682] LossD: 0.0171 LossG: 5.9479
# Epoch [18/500] Batch [2500/3682] LossD: 0.0062 LossG: 6.3760
# Epoch [18/500] Batch [2600/3682] LossD: 0.0237 LossG: 6.0422
# Epoch [18/500] Batch [2700/3682] LossD: 0.1182 LossG: 5.9806
# Epoch [18/500] Batch [2800/3682] LossD: 0.0181 LossG: 7.6606
# Epoch [18/500] Batch [2900/3682] LossD: 0.0120 LossG: 6.1815
# Epoch [18/500] Batch [3000/3682] LossD: 0.0180 LossG: 8.2272
# Epoch [18/500] Batch [3100/3682] LossD: 0.0267 LossG: 5.6770
# Epoch [18/500] Batch [3200/3682] LossD: 0.0319 LossG: 6.0616
# Epoch [18/500] Batch [3300/3682] LossD: 0.8021 LossG: 4.0362
# Epoch [18/500] Batch [3400/3682] LossD: 0.0132 LossG: 6.0859
# Epoch [18/500] Batch [3500/3682] LossD: 0.2269 LossG: 7.1061
# Epoch [18/500] Batch [3600/3682] LossD: 0.4096 LossG: 10.0623
# Sample image saved: samples/epoch_18.png
# Epoch [19/500] Batch [0/3682] LossD: 0.0489 LossG: 6.1991
# Epoch [19/500] Batch [100/3682] LossD: 0.4894 LossG: 7.5296
# Epoch [19/500] Batch [200/3682] LossD: 0.0899 LossG: 6.3737
# Epoch [19/500] Batch [300/3682] LossD: 0.0503 LossG: 5.8741
# Epoch [19/500] Batch [400/3682] LossD: 0.0514 LossG: 6.2506
# Epoch [19/500] Batch [500/3682] LossD: 0.0105 LossG: 6.8211
# Epoch [19/500] Batch [600/3682] LossD: 0.0271 LossG: 7.5092
# Epoch [19/500] Batch [700/3682] LossD: 0.0701 LossG: 6.2968
# Epoch [19/500] Batch [800/3682] LossD: 1.0025 LossG: 6.7500
# Epoch [19/500] Batch [900/3682] LossD: 0.0616 LossG: 6.7178
# Epoch [19/500] Batch [1000/3682] LossD: 0.0608 LossG: 8.2880
# Epoch [19/500] Batch [1100/3682] LossD: 0.0344 LossG: 7.1485
# Epoch [19/500] Batch [1200/3682] LossD: 0.0146 LossG: 6.7060
# Epoch [19/500] Batch [1300/3682] LossD: 0.0031 LossG: 8.3108
# Epoch [19/500] Batch [1400/3682] LossD: 0.0706 LossG: 4.6415
# Epoch [19/500] Batch [1500/3682] LossD: 0.1073 LossG: 9.7362
# Epoch [19/500] Batch [1600/3682] LossD: 0.0462 LossG: 5.4318
# Epoch [19/500] Batch [1700/3682] LossD: 0.0913 LossG: 6.9797
# Epoch [19/500] Batch [1800/3682] LossD: 0.0383 LossG: 6.0787
# Epoch [19/500] Batch [1900/3682] LossD: 0.0964 LossG: 5.5759
# Epoch [19/500] Batch [2000/3682] LossD: 0.0981 LossG: 4.5266
# Epoch [19/500] Batch [2100/3682] LossD: 0.1794 LossG: 8.4994
# Epoch [19/500] Batch [2200/3682] LossD: 0.0834 LossG: 5.0119
# Epoch [19/500] Batch [2300/3682] LossD: 0.1293 LossG: 7.4797
# Epoch [19/500] Batch [2400/3682] LossD: 0.0211 LossG: 7.5418
# Epoch [19/500] Batch [2500/3682] LossD: 0.0578 LossG: 5.6824
# Epoch [19/500] Batch [2600/3682] LossD: 0.1111 LossG: 5.4695
# Epoch [19/500] Batch [2700/3682] LossD: 0.1247 LossG: 3.6244
# Epoch [19/500] Batch [2800/3682] LossD: 0.0365 LossG: 7.3611
# Epoch [19/500] Batch [2900/3682] LossD: 0.0372 LossG: 7.5038
# Epoch [19/500] Batch [3000/3682] LossD: 0.0478 LossG: 5.4961
# Epoch [19/500] Batch [3100/3682] LossD: 0.3005 LossG: 4.8354
# Epoch [19/500] Batch [3200/3682] LossD: 0.2065 LossG: 3.2195
# Epoch [19/500] Batch [3300/3682] LossD: 0.0509 LossG: 6.1237
# Epoch [19/500] Batch [3400/3682] LossD: 0.0617 LossG: 6.4504
# Epoch [19/500] Batch [3500/3682] LossD: 0.0099 LossG: 7.7954
# Epoch [19/500] Batch [3600/3682] LossD: 0.0736 LossG: 5.9371
# Sample image saved: samples/epoch_19.png
# Epoch [20/500] Batch [0/3682] LossD: 0.0158 LossG: 9.3441
# Epoch [20/500] Batch [100/3682] LossD: 0.0096 LossG: 6.4148
# Epoch [20/500] Batch [200/3682] LossD: 0.0668 LossG: 4.6427
# Epoch [20/500] Batch [300/3682] LossD: 0.0735 LossG: 6.6038
# Epoch [20/500] Batch [400/3682] LossD: 0.0290 LossG: 8.1064
# Epoch [20/500] Batch [500/3682] LossD: 0.0207 LossG: 6.8438
# Epoch [20/500] Batch [600/3682] LossD: 0.0056 LossG: 7.1541
# Epoch [20/500] Batch [700/3682] LossD: 0.0372 LossG: 6.9598
# Epoch [20/500] Batch [800/3682] LossD: 0.0839 LossG: 8.3053
# Epoch [20/500] Batch [900/3682] LossD: 0.0984 LossG: 7.3526
# Epoch [20/500] Batch [1000/3682] LossD: 0.7611 LossG: 4.1871
# Epoch [20/500] Batch [1100/3682] LossD: 0.0133 LossG: 6.6694
# Epoch [20/500] Batch [1200/3682] LossD: 0.3694 LossG: 3.6199
# Epoch [20/500] Batch [1300/3682] LossD: 0.0293 LossG: 7.2307
# Epoch [20/500] Batch [1400/3682] LossD: 0.0259 LossG: 7.7222
# Epoch [20/500] Batch [1500/3682] LossD: 0.0443 LossG: 5.3398
# Epoch [20/500] Batch [1600/3682] LossD: 0.0842 LossG: 5.2273
# Epoch [20/500] Batch [1700/3682] LossD: 0.0251 LossG: 5.9549
# Epoch [20/500] Batch [1800/3682] LossD: 0.0244 LossG: 5.2142
# Epoch [20/500] Batch [1900/3682] LossD: 0.0868 LossG: 4.9239
# Epoch [20/500] Batch [2000/3682] LossD: 0.0497 LossG: 5.5199
# Epoch [20/500] Batch [2100/3682] LossD: 0.0109 LossG: 6.5925
# Epoch [20/500] Batch [2200/3682] LossD: 0.0264 LossG: 6.4924
# Epoch [20/500] Batch [2300/3682] LossD: 0.0308 LossG: 8.2702
# Epoch [20/500] Batch [2400/3682] LossD: 0.1764 LossG: 7.3641
# Epoch [20/500] Batch [2500/3682] LossD: 0.0300 LossG: 7.3536
# Epoch [20/500] Batch [2600/3682] LossD: 0.1160 LossG: 5.9671
# Epoch [20/500] Batch [2700/3682] LossD: 0.1582 LossG: 9.6425
# Epoch [20/500] Batch [2800/3682] LossD: 0.0125 LossG: 7.5857
# Epoch [20/500] Batch [2900/3682] LossD: 0.0123 LossG: 8.1722
# Epoch [20/500] Batch [3000/3682] LossD: 0.0852 LossG: 6.5000
# Epoch [20/500] Batch [3100/3682] LossD: 0.0108 LossG: 7.5461
# Epoch [20/500] Batch [3200/3682] LossD: 0.0694 LossG: 6.4797
# Epoch [20/500] Batch [3300/3682] LossD: 0.0117 LossG: 9.2704
# Epoch [20/500] Batch [3400/3682] LossD: 0.0448 LossG: 8.2275
# Epoch [20/500] Batch [3500/3682] LossD: 0.0756 LossG: 5.6940
# Epoch [20/500] Batch [3600/3682] LossD: 0.0853 LossG: 6.2770
# Sample image saved: samples/epoch_20.png
# Epoch [21/500] Batch [0/3682] LossD: 0.3626 LossG: 7.9015
# Epoch [21/500] Batch [100/3682] LossD: 0.0322 LossG: 5.6608
# Epoch [21/500] Batch [200/3682] LossD: 0.0167 LossG: 7.0651
# Epoch [21/500] Batch [300/3682] LossD: 0.0349 LossG: 5.7194
# Epoch [21/500] Batch [400/3682] LossD: 0.0452 LossG: 5.6879
# Epoch [21/500] Batch [500/3682] LossD: 0.0041 LossG: 7.6672
# Epoch [21/500] Batch [600/3682] LossD: 0.0354 LossG: 5.8239
# Epoch [21/500] Batch [700/3682] LossD: 0.0801 LossG: 6.8867
# Epoch [21/500] Batch [800/3682] LossD: 0.0244 LossG: 7.1167
# Epoch [21/500] Batch [900/3682] LossD: 0.0952 LossG: 4.2995
# Epoch [21/500] Batch [1000/3682] LossD: 0.0929 LossG: 5.9795
# Epoch [21/500] Batch [1100/3682] LossD: 0.0673 LossG: 7.1390
# Epoch [21/500] Batch [1200/3682] LossD: 0.0111 LossG: 7.7217
# Epoch [21/500] Batch [1300/3682] LossD: 0.0079 LossG: 6.6008
# Epoch [21/500] Batch [1400/3682] LossD: 0.0538 LossG: 6.5618
# Epoch [21/500] Batch [1500/3682] LossD: 0.2173 LossG: 8.3406
# Epoch [21/500] Batch [1600/3682] LossD: 0.0241 LossG: 6.2856
# Epoch [21/500] Batch [1700/3682] LossD: 0.0419 LossG: 12.9011
# Epoch [21/500] Batch [1800/3682] LossD: 0.0226 LossG: 5.9523
# Epoch [21/500] Batch [1900/3682] LossD: 0.0434 LossG: 5.8478
# Epoch [21/500] Batch [2000/3682] LossD: 0.0162 LossG: 6.8892
# Epoch [21/500] Batch [2100/3682] LossD: 0.0323 LossG: 6.6995
# Epoch [21/500] Batch [2200/3682] LossD: 0.0135 LossG: 6.7063
# Epoch [21/500] Batch [2300/3682] LossD: 0.0111 LossG: 7.2472
# Epoch [21/500] Batch [2400/3682] LossD: 0.0057 LossG: 7.5251
# Epoch [21/500] Batch [2500/3682] LossD: 0.0479 LossG: 7.5505
# Epoch [21/500] Batch [2600/3682] LossD: 0.0636 LossG: 8.1507
# Epoch [21/500] Batch [2700/3682] LossD: 0.7745 LossG: 0.2542
# Epoch [21/500] Batch [2800/3682] LossD: 0.0271 LossG: 6.1391
# Epoch [21/500] Batch [2900/3682] LossD: 0.0194 LossG: 6.4056
# Epoch [21/500] Batch [3000/3682] LossD: 0.0017 LossG: 14.0125
# Epoch [21/500] Batch [3100/3682] LossD: 0.0240 LossG: 7.3027
# Epoch [21/500] Batch [3200/3682] LossD: 0.0439 LossG: 6.4966
# Epoch [21/500] Batch [3300/3682] LossD: 0.0094 LossG: 9.7059
# Epoch [21/500] Batch [3400/3682] LossD: 0.0192 LossG: 6.1242
# Epoch [21/500] Batch [3500/3682] LossD: 0.0107 LossG: 6.5516
# Epoch [21/500] Batch [3600/3682] LossD: 0.0190 LossG: 6.6913
# Sample image saved: samples/epoch_21.png
# Epoch [22/500] Batch [0/3682] LossD: 0.3661 LossG: 16.1725
# Epoch [22/500] Batch [100/3682] LossD: 0.0536 LossG: 8.5891
# Epoch [22/500] Batch [200/3682] LossD: 0.0225 LossG: 6.1906
# Epoch [22/500] Batch [300/3682] LossD: 0.0325 LossG: 6.5965
# Epoch [22/500] Batch [400/3682] LossD: 0.2896 LossG: 4.3748
# ...
# Epoch [44/500] Batch [2200/3682] LossD: 0.0049 LossG: 8.6902
# Epoch [44/500] Batch [2300/3682] LossD: 0.0385 LossG: 6.9772
# Epoch [44/500] Batch [2400/3682] LossD: 0.0312 LossG: 7.3450
# Epoch [44/500] Batch [2500/3682] LossD: 0.0142 LossG: 8.1580
# Epoch [44/500] Batch [2600/3682] LossD: 0.0313 LossG: 8.7201
# Epoch [44/500] Batch [2700/3682] LossD: 0.0152 LossG: 7.7032
# Epoch [44/500] Batch [2800/3682] LossD: 0.0042 LossG: 7.7688
# Epoch [44/500] Batch [2900/3682] LossD: 0.0270 LossG: 5.9573
# Epoch [44/500] Batch [3000/3682] LossD: 0.1502 LossG: 7.1132
# Epoch [44/500] Batch [3100/3682] LossD: 0.0375 LossG: 8.2062
# Epoch [44/500] Batch [3200/3682] LossD: 0.0066 LossG: 9.9344
# Epoch [44/500] Batch [3300/3682] LossD: 0.0574 LossG: 7.5527
# Epoch [44/500] Batch [3400/3682] LossD: 0.0484 LossG: 7.6428
# Epoch [44/500] Batch [3500/3682] LossD: 0.0532 LossG: 7.9604
# Epoch [44/500] Batch [3600/3682] LossD: 0.0165 LossG: 9.3032
# Sample image saved: samples/epoch_44.png
# Epoch [45/500] Batch [0/3682] LossD: 0.0048 LossG: 8.0530
# Epoch [45/500] Batch [100/3682] LossD: 0.0113 LossG: 8.0111
# Epoch [45/500] Batch [200/3682] LossD: 0.0041 LossG: 10.2297
# Epoch [45/500] Batch [300/3682] LossD: 0.1737 LossG: 3.9796
# Epoch [45/500] Batch [400/3682] LossD: 0.0037 LossG: 9.8483
# Epoch [45/500] Batch [500/3682] LossD: 20.5564 LossG: 8.0284
# Epoch [45/500] Batch [600/3682] LossD: 0.0169 LossG: 7.2792
# Epoch [45/500] Batch [700/3682] LossD: 0.0547 LossG: 8.1718
# Epoch [45/500] Batch [800/3682] LossD: 0.2028 LossG: 4.1003
# Epoch [45/500] Batch [900/3682] LossD: 0.0108 LossG: 7.0636
# Epoch [45/500] Batch [1000/3682] LossD: 0.0079 LossG: 6.5334
# Epoch [45/500] Batch [1100/3682] LossD: 0.1009 LossG: 6.4883
# Epoch [45/500] Batch [1200/3682] LossD: 0.0060 LossG: 8.7758
# Epoch [45/500] Batch [1300/3682] LossD: 0.1395 LossG: 11.1674
# Epoch [45/500] Batch [1400/3682] LossD: 0.0232 LossG: 7.9865
# Epoch [45/500] Batch [1500/3682] LossD: 0.2254 LossG: 13.2726
# Epoch [45/500] Batch [1600/3682] LossD: 0.0031 LossG: 6.9587
# Epoch [45/500] Batch [1700/3682] LossD: 0.0784 LossG: 9.9066
# Epoch [45/500] Batch [1800/3682] LossD: 0.0785 LossG: 7.4192
# Epoch [45/500] Batch [1900/3682] LossD: 0.0174 LossG: 7.3110
# Epoch [45/500] Batch [2000/3682] LossD: 0.0384 LossG: 8.8855
# Epoch [45/500] Batch [2100/3682] LossD: 0.0601 LossG: 8.3765
# Epoch [45/500] Batch [2200/3682] LossD: 0.0134 LossG: 6.4441
# Epoch [45/500] Batch [2300/3682] LossD: 0.0013 LossG: 8.3533
# Epoch [45/500] Batch [2400/3682] LossD: 0.0157 LossG: 8.3832
# Epoch [45/500] Batch [2500/3682] LossD: 0.0021 LossG: 11.6886
# Epoch [45/500] Batch [2600/3682] LossD: 0.0078 LossG: 10.3321
# Epoch [45/500] Batch [2700/3682] LossD: 0.0238 LossG: 7.1692
# Epoch [45/500] Batch [2800/3682] LossD: 0.0070 LossG: 7.5127
# Epoch [45/500] Batch [2900/3682] LossD: 0.0169 LossG: 6.5379
# Epoch [45/500] Batch [3000/3682] LossD: 0.0284 LossG: 7.0947
# Epoch [45/500] Batch [3100/3682] LossD: 0.0223 LossG: 7.5716
# Epoch [45/500] Batch [3200/3682] LossD: 0.0055 LossG: 7.9806
# Epoch [45/500] Batch [3300/3682] LossD: 0.0343 LossG: 7.8808
# Epoch [45/500] Batch [3400/3682] LossD: 0.8615 LossG: 1.4085
# Epoch [45/500] Batch [3500/3682] LossD: 0.0142 LossG: 7.7922
# Epoch [45/500] Batch [3600/3682] LossD: 0.0096 LossG: 15.2763
# Sample image saved: samples/epoch_45.png
# Epoch [46/500] Batch [0/3682] LossD: 0.1004 LossG: 11.3723
# Epoch [46/500] Batch [100/3682] LossD: 0.0106 LossG: 7.2850
# Epoch [46/500] Batch [200/3682] LossD: 0.1990 LossG: 13.5610
# Epoch [46/500] Batch [300/3682] LossD: 0.1554 LossG: 4.9804
# Epoch [46/500] Batch [400/3682] LossD: 0.0061 LossG: 8.5393
# Epoch [46/500] Batch [500/3682] LossD: 0.1205 LossG: 5.7922
# Epoch [46/500] Batch [600/3682] LossD: 0.0268 LossG: 7.8854
# Epoch [46/500] Batch [700/3682] LossD: 0.0098 LossG: 8.2696
# Epoch [46/500] Batch [800/3682] LossD: 0.0160 LossG: 7.1782
# Epoch [46/500] Batch [900/3682] LossD: 0.0118 LossG: 8.9446
# Epoch [46/500] Batch [1000/3682] LossD: 0.0224 LossG: 7.1706
# Epoch [46/500] Batch [1100/3682] LossD: 0.0055 LossG: 7.2478
# Epoch [46/500] Batch [1200/3682] LossD: 0.0493 LossG: 6.7391
# Epoch [46/500] Batch [1300/3682] LossD: 0.0005 LossG: 10.9117
# Epoch [46/500] Batch [1400/3682] LossD: 0.2968 LossG: 5.4178
# Epoch [46/500] Batch [1500/3682] LossD: 0.0014 LossG: 10.5114
# Epoch [46/500] Batch [1600/3682] LossD: 0.0201 LossG: 6.1814
# Epoch [46/500] Batch [1700/3682] LossD: 0.0859 LossG: 8.2670
# Epoch [46/500] Batch [1800/3682] LossD: 0.0399 LossG: 7.3180
# Epoch [46/500] Batch [1900/3682] LossD: 0.0716 LossG: 9.6273
# Epoch [46/500] Batch [2000/3682] LossD: 0.0115 LossG: 7.0980
# Epoch [46/500] Batch [2100/3682] LossD: 0.0071 LossG: 9.5236
# Epoch [46/500] Batch [2200/3682] LossD: 0.0124 LossG: 9.8477
# Epoch [46/500] Batch [2300/3682] LossD: 0.0080 LossG: 8.0463
# Epoch [46/500] Batch [2400/3682] LossD: 0.0189 LossG: 8.7095
# Epoch [46/500] Batch [2500/3682] LossD: 0.0043 LossG: 8.0863
# Epoch [46/500] Batch [2600/3682] LossD: 0.0099 LossG: 9.4987
# Epoch [46/500] Batch [2700/3682] LossD: 0.0442 LossG: 6.9249
# Epoch [46/500] Batch [2800/3682] LossD: 0.2655 LossG: 14.7297
# Epoch [46/500] Batch [2900/3682] LossD: 0.0082 LossG: 6.9317
# Epoch [46/500] Batch [3000/3682] LossD: 0.0211 LossG: 7.4443
# Epoch [46/500] Batch [3100/3682] LossD: 0.0011 LossG: 11.0221
# Epoch [46/500] Batch [3200/3682] LossD: 0.0456 LossG: 5.9055
# Epoch [46/500] Batch [3300/3682] LossD: 0.0062 LossG: 7.5492
# Epoch [46/500] Batch [3400/3682] LossD: 0.0664 LossG: 6.3166
# Epoch [46/500] Batch [3500/3682] LossD: 0.1178 LossG: 8.6653
# Epoch [46/500] Batch [3600/3682] LossD: 0.0175 LossG: 6.9224
# Sample image saved: samples/epoch_46.png
# Epoch [47/500] Batch [0/3682] LossD: 0.1860 LossG: 5.8449
# Epoch [47/500] Batch [100/3682] LossD: 0.0325 LossG: 7.0722
# Epoch [47/500] Batch [200/3682] LossD: 0.0053 LossG: 7.9841
# Epoch [47/500] Batch [300/3682] LossD: 0.0225 LossG: 9.2389
# Epoch [47/500] Batch [400/3682] LossD: 0.1100 LossG: 10.1582
# Epoch [47/500] Batch [500/3682] LossD: 0.0400 LossG: 7.6580
# Epoch [47/500] Batch [600/3682] LossD: 0.0208 LossG: 5.9615
# Epoch [47/500] Batch [700/3682] LossD: 0.0076 LossG: 7.1678
# Epoch [47/500] Batch [800/3682] LossD: 0.0190 LossG: 7.1272
# Epoch [47/500] Batch [900/3682] LossD: 0.0075 LossG: 7.8692
# Epoch [47/500] Batch [1000/3682] LossD: 0.0503 LossG: 7.7028
# Epoch [47/500] Batch [1100/3682] LossD: 0.0242 LossG: 7.3332
# Epoch [47/500] Batch [1200/3682] LossD: 0.0155 LossG: 7.2319
# Epoch [47/500] Batch [1300/3682] LossD: 0.0644 LossG: 6.9362
# Epoch [47/500] Batch [1400/3682] LossD: 0.0266 LossG: 5.5336
# Epoch [47/500] Batch [1500/3682] LossD: 0.0078 LossG: 7.1254
# Epoch [47/500] Batch [1600/3682] LossD: 0.0706 LossG: 7.8782
# Epoch [47/500] Batch [1700/3682] LossD: 0.0017 LossG: 8.6336
# Epoch [47/500] Batch [1800/3682] LossD: 0.0002 LossG: 10.4602
# Epoch [47/500] Batch [1900/3682] LossD: 0.0273 LossG: 9.1270
# Epoch [47/500] Batch [2000/3682] LossD: 0.0006 LossG: 9.6054
# Epoch [47/500] Batch [2100/3682] LossD: 0.0194 LossG: 9.6451
# Epoch [47/500] Batch [2200/3682] LossD: 0.0948 LossG: 8.1622
# Epoch [47/500] Batch [2300/3682] LossD: 0.2588 LossG: 8.7472
# Epoch [47/500] Batch [2400/3682] LossD: 0.0347 LossG: 8.1673
# Epoch [47/500] Batch [2500/3682] LossD: 0.0229 LossG: 7.6142
# Epoch [47/500] Batch [2600/3682] LossD: 0.0134 LossG: 7.4631
# Epoch [47/500] Batch [2700/3682] LossD: 0.1157 LossG: 6.1658
# Epoch [47/500] Batch [2800/3682] LossD: 0.0051 LossG: 8.4457
# Epoch [47/500] Batch [2900/3682] LossD: 0.0116 LossG: 8.3628
# Epoch [47/500] Batch [3000/3682] LossD: 0.0042 LossG: 7.4808
# Epoch [47/500] Batch [3100/3682] LossD: 0.0513 LossG: 7.2244
# Epoch [47/500] Batch [3200/3682] LossD: 0.0304 LossG: 5.8729
# Epoch [47/500] Batch [3300/3682] LossD: 0.0068 LossG: 10.8458
# Epoch [47/500] Batch [3400/3682] LossD: 0.0131 LossG: 9.4780
# Epoch [47/500] Batch [3500/3682] LossD: 0.0160 LossG: 7.1709
# Epoch [47/500] Batch [3600/3682] LossD: 0.0017 LossG: 10.7156
# Sample image saved: samples/epoch_47.png
# Epoch [48/500] Batch [0/3682] LossD: 0.0087 LossG: 7.7664
# Epoch [48/500] Batch [100/3682] LossD: 0.0080 LossG: 8.1002
# Epoch [48/500] Batch [200/3682] LossD: 0.0178 LossG: 7.9602
# Epoch [48/500] Batch [300/3682] LossD: 0.0141 LossG: 7.6634
# Epoch [48/500] Batch [400/3682] LossD: 0.0232 LossG: 8.3153
# Epoch [48/500] Batch [500/3682] LossD: 0.0135 LossG: 7.0813
# Epoch [48/500] Batch [600/3682] LossD: 0.0115 LossG: 11.5158
# Epoch [48/500] Batch [700/3682] LossD: 0.0030 LossG: 8.8086
# Epoch [48/500] Batch [800/3682] LossD: 0.0020 LossG: 14.1119
# Epoch [48/500] Batch [900/3682] LossD: 0.0156 LossG: 7.0917
# Epoch [48/500] Batch [1000/3682] LossD: 0.0060 LossG: 6.0876
# Epoch [48/500] Batch [1100/3682] LossD: 0.0022 LossG: 8.7042
# Epoch [48/500] Batch [1200/3682] LossD: 0.0329 LossG: 7.2478
# Epoch [48/500] Batch [1300/3682] LossD: 0.1561 LossG: 7.1124
# Epoch [48/500] Batch [1400/3682] LossD: 0.0290 LossG: 6.4551
# Epoch [48/500] Batch [1500/3682] LossD: 0.0039 LossG: 9.0645
# Epoch [48/500] Batch [1600/3682] LossD: 0.0223 LossG: 7.5681
# Epoch [48/500] Batch [1700/3682] LossD: 0.0254 LossG: 11.7685
# Epoch [48/500] Batch [1800/3682] LossD: 0.0059 LossG: 9.5402
# Epoch [48/500] Batch [1900/3682] LossD: 0.0013 LossG: 12.3747
# Epoch [48/500] Batch [2000/3682] LossD: 0.0098 LossG: 7.8415
# Epoch [48/500] Batch [2100/3682] LossD: 0.0038 LossG: 11.3378
# Epoch [48/500] Batch [2200/3682] LossD: 0.0409 LossG: 7.1139
# Epoch [48/500] Batch [2300/3682] LossD: 0.0509 LossG: 8.6777
# Epoch [48/500] Batch [2400/3682] LossD: 0.0079 LossG: 8.4831
# Epoch [48/500] Batch [2500/3682] LossD: 0.0332 LossG: 7.5037
# Epoch [48/500] Batch [2600/3682] LossD: 0.0192 LossG: 7.3502
# Epoch [48/500] Batch [2700/3682] LossD: 0.0714 LossG: 8.4202
# Epoch [48/500] Batch [2800/3682] LossD: 0.0221 LossG: 7.9672
# Epoch [48/500] Batch [2900/3682] LossD: 0.1180 LossG: 7.2902
# Epoch [48/500] Batch [3000/3682] LossD: 0.0306 LossG: 9.0761
# Epoch [48/500] Batch [3100/3682] LossD: 0.0215 LossG: 12.5531
# Epoch [48/500] Batch [3200/3682] LossD: 0.0060 LossG: 9.9093
# Epoch [48/500] Batch [3300/3682] LossD: 0.0102 LossG: 7.4843
# Epoch [48/500] Batch [3400/3682] LossD: 0.0016 LossG: 9.7433
# Epoch [48/500] Batch [3500/3682] LossD: 0.0416 LossG: 8.1164
# Epoch [48/500] Batch [3600/3682] LossD: 0.0215 LossG: 6.9799
# Sample image saved: samples/epoch_48.png
# Epoch [49/500] Batch [0/3682] LossD: 0.4094 LossG: 15.0073
# Epoch [49/500] Batch [100/3682] LossD: 0.0221 LossG: 10.4013
# Epoch [49/500] Batch [200/3682] LossD: 0.0061 LossG: 8.6291
# Epoch [49/500] Batch [300/3682] LossD: 0.0031 LossG: 8.3943
# Epoch [49/500] Batch [400/3682] LossD: 0.0906 LossG: 8.9251
# Epoch [49/500] Batch [500/3682] LossD: 0.3709 LossG: 10.3723
# Epoch [49/500] Batch [600/3682] LossD: 0.0704 LossG: 9.6972
# Epoch [49/500] Batch [700/3682] LossD: 0.0108 LossG: 9.0010
# Epoch [49/500] Batch [800/3682] LossD: 0.0059 LossG: 8.4212
# Epoch [49/500] Batch [900/3682] LossD: 0.0027 LossG: 8.6058
# Epoch [49/500] Batch [1000/3682] LossD: 0.0016 LossG: 12.5906
# Epoch [49/500] Batch [1100/3682] LossD: 0.0132 LossG: 7.9658
# Epoch [49/500] Batch [1200/3682] LossD: 0.0386 LossG: 6.1409
# Epoch [49/500] Batch [1300/3682] LossD: 0.0016 LossG: 10.0811
# Epoch [49/500] Batch [1400/3682] LossD: 0.0060 LossG: 9.0361
# Epoch [49/500] Batch [1500/3682] LossD: 0.0020 LossG: 9.6890
# Epoch [49/500] Batch [1600/3682] LossD: 0.0123 LossG: 7.4306
# Epoch [49/500] Batch [1700/3682] LossD: 0.0076 LossG: 9.1606
# Epoch [49/500] Batch [1800/3682] LossD: 0.0042 LossG: 8.2240
# Epoch [49/500] Batch [1900/3682] LossD: 0.0049 LossG: 10.5722
# Epoch [49/500] Batch [2000/3682] LossD: 0.0297 LossG: 12.6066
# Epoch [49/500] Batch [2100/3682] LossD: 0.0702 LossG: 5.1067
# Epoch [49/500] Batch [2200/3682] LossD: 0.0407 LossG: 7.2973
# Epoch [49/500] Batch [2300/3682] LossD: 0.0561 LossG: 7.3637
# Epoch [49/500] Batch [2400/3682] LossD: 0.0286 LossG: 10.6658
# Epoch [49/500] Batch [2500/3682] LossD: 0.1520 LossG: 8.3946
# Epoch [49/500] Batch [2600/3682] LossD: 0.0020 LossG: 8.4357
# Epoch [49/500] Batch [2700/3682] LossD: 0.0129 LossG: 7.4080
# Epoch [49/500] Batch [2800/3682] LossD: 0.0079 LossG: 8.1071
# Epoch [49/500] Batch [2900/3682] LossD: 0.0119 LossG: 9.2221
# Epoch [49/500] Batch [3000/3682] LossD: 0.0033 LossG: 9.0679
# Epoch [49/500] Batch [3100/3682] LossD: 0.0040 LossG: 7.0421
# Epoch [49/500] Batch [3200/3682] LossD: 0.1052 LossG: 5.9651
# Epoch [49/500] Batch [3300/3682] LossD: 0.0173 LossG: 8.0072
# Epoch [49/500] Batch [3400/3682] LossD: 0.0302 LossG: 7.6497
# Epoch [49/500] Batch [3500/3682] LossD: 0.0171 LossG: 6.2818
# Epoch [49/500] Batch [3600/3682] LossD: 0.0430 LossG: 6.8832
# Sample image saved: samples/epoch_49.png
# Epoch [50/500] Batch [0/3682] LossD: 0.0251 LossG: 9.5796
# Epoch [50/500] Batch [100/3682] LossD: 1.0219 LossG: 11.6347
# Epoch [50/500] Batch [200/3682] LossD: 0.0079 LossG: 7.8474
# Epoch [50/500] Batch [300/3682] LossD: 0.0089 LossG: 8.6943
# Epoch [50/500] Batch [400/3682] LossD: 0.0261 LossG: 7.7353
# Epoch [50/500] Batch [500/3682] LossD: 0.0251 LossG: 5.9598
# Epoch [50/500] Batch [600/3682] LossD: 0.0056 LossG: 10.8886
# Epoch [50/500] Batch [700/3682] LossD: 3.9600 LossG: 5.8439
# Epoch [50/500] Batch [800/3682] LossD: 0.0050 LossG: 9.0489
# Epoch [50/500] Batch [900/3682] LossD: 0.0225 LossG: 6.6441
# Epoch [50/500] Batch [1000/3682] LossD: 0.0127 LossG: 8.5271
# Epoch [50/500] Batch [1100/3682] LossD: 0.0521 LossG: 8.5033
# Epoch [50/500] Batch [1200/3682] LossD: 0.0554 LossG: 8.7130
# Epoch [50/500] Batch [1300/3682] LossD: 0.0023 LossG: 9.5972
# Epoch [50/500] Batch [1400/3682] LossD: 0.0028 LossG: 8.7010
# Epoch [50/500] Batch [1500/3682] LossD: 0.0202 LossG: 7.5916
# Epoch [50/500] Batch [1600/3682] LossD: 0.0204 LossG: 7.3376
# Epoch [50/500] Batch [1700/3682] LossD: 0.1017 LossG: 10.3812
# Epoch [50/500] Batch [1800/3682] LossD: 0.0341 LossG: 9.1919
# Epoch [50/500] Batch [1900/3682] LossD: 0.0054 LossG: 11.3512
# Epoch [50/500] Batch [2000/3682] LossD: 0.0558 LossG: 8.0013
# Epoch [50/500] Batch [2100/3682] LossD: 0.0910 LossG: 8.7507
# Epoch [50/500] Batch [2200/3682] LossD: 0.3804 LossG: 17.0985
# Epoch [50/500] Batch [2300/3682] LossD: 0.0041 LossG: 8.2124
# Epoch [50/500] Batch [2400/3682] LossD: 0.0535 LossG: 8.8229
# Epoch [50/500] Batch [2500/3682] LossD: 0.0126 LossG: 8.5437
# Epoch [50/500] Batch [2600/3682] LossD: 0.0156 LossG: 8.6787
# Epoch [50/500] Batch [2700/3682] LossD: 0.0170 LossG: 9.2226
# Epoch [50/500] Batch [2800/3682] LossD: 0.0279 LossG: 6.9627
# Epoch [50/500] Batch [2900/3682] LossD: 0.0035 LossG: 8.8890
# Epoch [50/500] Batch [3000/3682] LossD: 0.0848 LossG: 9.5993
# Epoch [50/500] Batch [3100/3682] LossD: 0.0080 LossG: 9.1058
# Epoch [50/500] Batch [3200/3682] LossD: 0.0080 LossG: 7.4386
# Epoch [50/500] Batch [3300/3682] LossD: 0.0116 LossG: 7.9709
# Epoch [50/500] Batch [3400/3682] LossD: 0.0069 LossG: 7.3249
# Epoch [50/500] Batch [3500/3682] LossD: 0.1663 LossG: 6.2554
# Epoch [50/500] Batch [3600/3682] LossD: 0.0562 LossG: 8.3902
# Sample image saved: samples/epoch_50.png
# Epoch [51/500] Batch [0/3682] LossD: 0.1282 LossG: 6.4731
# Epoch [51/500] Batch [100/3682] LossD: 0.0053 LossG: 8.6948
# Epoch [51/500] Batch [200/3682] LossD: 0.0089 LossG: 7.1588
# Epoch [51/500] Batch [300/3682] LossD: 1.6638 LossG: 25.2206
# Epoch [51/500] Batch [400/3682] LossD: 0.0103 LossG: 8.2154
# Epoch [51/500] Batch [500/3682] LossD: 0.0701 LossG: 6.9508
# Epoch [51/500] Batch [600/3682] LossD: 0.0113 LossG: 7.3714
# Epoch [51/500] Batch [700/3682] LossD: 0.0154 LossG: 7.9090
# Epoch [51/500] Batch [800/3682] LossD: 0.0031 LossG: 13.6706
# Epoch [51/500] Batch [900/3682] LossD: 0.0043 LossG: 8.8102
# Epoch [51/500] Batch [1000/3682] LossD: 0.0592 LossG: 7.1181
# Epoch [51/500] Batch [1100/3682] LossD: 0.0034 LossG: 11.1188
# Epoch [51/500] Batch [1200/3682] LossD: 0.0239 LossG: 6.9023
# Epoch [51/500] Batch [1300/3682] LossD: 0.0829 LossG: 5.1155
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 53
#      50 optimizerG.step()
#      52 # Simpan history loss (opsional: per batch, atau rata2 per epoch)
# ---> 53 lossD_history.append(lossD_total.item())
#      54 lossG_history.append(lossG_total.item())
#      56 if i % 100 == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot Training Loss

# %%
plt.figure(figsize=(10,5))
plt.title("Training Loss D & G")
plt.plot(lossD_history, label="LossD")
plt.plot(lossG_history, label="LossG")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend()
plt.savefig("training_loss_plot.png")
plt.show()
print("Plot saved: training_loss_plot.png")
# Out:
# Plot saved: training_loss_plot.png

# %%
# Visualisasi Loss D
plt.figure(figsize=(10, 5))
plt.title("Training Loss D")
plt.plot(lossD_history, label="LossD")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend()
plt.savefig("training_lossD_plot.png")
plt.show()
print("Plot saved: training_lossD_plot.png")

# Visualisasi Loss G
plt.figure(figsize=(10, 5))
plt.title("Training Loss G")
plt.plot(lossG_history, label="LossG")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend()
plt.savefig("training_lossG_plot.png")
plt.show()
print("Plot saved: training_lossG_plot.png")
# Out:
# Plot saved: training_lossD_plot.png
# Plot saved: training_lossG_plot.png

# %% [markdown]
# ### Evaluasi FID (NOT USE FOR NOW)

# %%
# # Contoh cara menghitung FID menggunakan pytorch-fid:
# #
# # 1) Install pytorch-fid:
# #    pip install pytorch-fid
# # 2) Generate sejumlah fake images, simpan di folder khusus
# #    Kumpulkan juga real images di folder lain.
# # 3) Jalankan:
# #    python -m pytorch_fid path/to/real_images path/to/fake_images
# #
# # Di bawah ini contoh kode untuk simpan fake images & real images.
#
# def save_fake_images_for_fid(generator, save_dir="fake_for_fid", num_images=500):
#     os.makedirs(save_dir, exist_ok=True)
#     generator.eval()
#     with torch.no_grad():
#         for idx in range(num_images):
#             z = torch.randn(1, nz, 1, 1, device=device)
#             fake = generator(z).cpu()
#             # Normal range is [-1,1], convert to [0,1]
#             fake = (fake + 1)/2
#             fake_clamped = torch.clamp(fake, 0, 1)
#             save_image(fake_clamped, os.path.join(save_dir, f"fake_{idx}.png"))
#
# def save_real_images_for_fid(dataset, save_dir="real_for_fid", num_images=500):
#     os.makedirs(save_dir, exist_ok=True)
#     count = 0
#     for i, (img, _) in enumerate(dataset):
#         if count >= num_images:
#             break
#         # convert [-1,1] or [0,1] -> [0,1] (tergantung transform)
#         # Saat ini dataset di-normalize ke [-1,1] => kita kembalikan
#         img = (img * 0.5) + 0.5
#         img = torch.clamp(img, 0, 1)
#         # unsqueeze batch dimension
#         save_image(img, os.path.join(save_dir, f"real_{count}.png"))
#         count += 1
#
# # Cara penggunaannya (uncomment jika ingin pakai):
# # save_fake_images_for_fid(netG, "fake_for_fid", num_images=200)
# # save_real_images_for_fid(dataset, "real_for_fid", num_images=200)
# #
# # Setelah folder "fake_for_fid" dan "real_for_fid" terisi, jalankan di Terminal:
# #    python -m pytorch_fid real_for_fid fake_for_fid
#
# # -------------------------------------------------------------
# # Bagian 7: Visualisasi Latent Space (t-SNE) [Opsional]
# # -------------------------------------------------------------
# # Kadang kita ingin melihat sebaran vektor noise (z).
# # t-SNE bermanfaat jika kita punya label (tapi di DCGAN unlabeled).
# # Berikut contoh minimal:
#
# """
# from sklearn.manifold import TSNE
# import numpy as np
#
# def visualize_latent_tsne(num_samples=500):
#     # Kita sampling z random, lalu project ke 2D
#     netG.eval()
#     all_z = []
#     for _ in range(num_samples):
#         z = torch.randn(1, nz, 1, 1, device=device)
#         all_z.append(z.view(1, -1).cpu().numpy())  # (1, nz)
#     all_z = np.concatenate(all_z, axis=0)  # shape (num_samples, nz)
#
#     tsne = TSNE(n_components=2, perplexity=30, n_iter=1000)
#     z_2d = tsne.fit_transform(all_z)
#
#     plt.figure(figsize=(8,6))
#     plt.scatter(z_2d[:,0], z_2d[:,1], alpha=0.7, s=10, c='blue')
#     plt.title("t-SNE of Random Noise Z (DCGAN)")
#     plt.xlabel("Dimension 1")
#     plt.ylabel("Dimension 2")
#     plt.show()
#
# # Jalankan jika mau:
# # visualize_latent_tsne()
# """

# %% [markdown]
# ### Visualisasi Latent Space (t-SNE)

# %%
def visualize_latent_tsne(modelG, num_samples=500):
    """
    Fungsi ini mengambil 'num_samples' random noise,
    lalu memplot distribusinya di 2D dengan TSNE.
    """
    modelG.eval()
    all_z = []
    for _ in range(num_samples):
        z = torch.randn(1, nz, 1, 1, device=device)  # (1, nz, 1, 1)
        # Flatten (1, nz*1*1) => (1, nz)
        all_z.append(z.view(1, -1).cpu().numpy())
    all_z = np.concatenate(all_z, axis=0)  # (num_samples, nz)

    print("Running t-SNE on latent vectors. Might take a while ...")
    tsne = TSNE(n_components=2, perplexity=30, n_iter=1000)
    z_2d = tsne.fit_transform(all_z)

    plt.figure(figsize=(8,6))
    plt.scatter(z_2d[:,0], z_2d[:,1], alpha=0.7, s=10, c='blue')
    plt.title("t-SNE of Random Noise Z (DCGAN)")
    plt.xlabel("Dimension 1")
    plt.ylabel("Dimension 2")
    plt.show()

    print("t-SNE plot displayed above.")

# %% [markdown]
# #### Saving Model

# %%
def save_dcgan_models(netG, netD, i):
    """
    Menyimpan model generator & discriminator DCGAN
    dengan nama file Model_DCGAN_Ver_(i+i).pth.

    Parameter:
    - netG: model Generator
    - netD: model Discriminator
    - i   : angka versi (integer)
    """
    # Pastikan folder "saved_models" (atau nama lain) ada
    os.makedirs("saved_models", exist_ok=True)

    # Format penamaan file
    generator_filename = f"Model_DCGAN_Gen_Ver_{i+i}.pth"
    discriminator_filename = f"Model_DCGAN_Dis_Ver_{i+i}.pth"

    # Lokasi file (gabungkan dengan folder "saved_models")
    generator_path = os.path.join("saved_models", generator_filename)
    discriminator_path = os.path.join("saved_models", discriminator_filename)

    # Simpan state_dict model
    torch.save(netG.state_dict(), generator_path)
    torch.save(netD.state_dict(), discriminator_path)

    print(f"Generator DCGAN disimpan di: {generator_path}")
    print(f"Discriminator DCGAN disimpan di: {discriminator_path}")

# -------------------------------------------------------------
# Contoh penggunaan di luar training
# -------------------------------------------------------------
# Misal Anda sudah selesai training netG dan netD.
# Anggap 'netG' dan 'netD' adalah instance dari Generator & Discriminator
# DCGAN yang telah dilatih.

# Contoh saja, misalnya versi i=5
i = 5

# Panggil fungsi penyimpanan
save_dcgan_models(netG, netD, i)
# Out:
# Generator DCGAN disimpan di: saved_models\Model_DCGAN_Gen_Ver_10.pth
# Discriminator DCGAN disimpan di: saved_models\Model_DCGAN_Dis_Ver_10.pth
